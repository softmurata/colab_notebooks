# %% [markdown]
# <a href="https://colab.research.google.com/github/softmurata/colab_notebooks/blob/main/ocr/deep_text_recognition_benchmark_original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This can be executed in https://colab.research.google.com "Python 3 / GPU" runtime.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/clovaai/deep-text-recognition-benchmark
# %cd deep-text-recognition-benchmark

# %% [markdown]
# Next, download large model files from Google Drive, using hack: https://stackoverflow.com/questions/20665881/direct-download-from-google-drive-using-google-drive-api/32742700#32742700

# %%
models = {
    'None-ResNet-None-CTC.pth': 'https://drive.google.com/open?id=1FocnxQzFBIjDT2F9BkNUiLdo1cC3eaO0',
    'None-VGG-BiLSTM-CTC.pth': 'https://drive.google.com/open?id=1GGC2IRYEMQviZhqQpbtpeTgHO_IXWetG',
    'None-VGG-None-CTC.pth': 'https://drive.google.com/open?id=1FS3aZevvLiGF1PFBm5SkwvVcgI6hJWL9',
    'TPS-ResNet-BiLSTM-Attn-case-sensitive.pth': 'https://drive.google.com/open?id=1ajONZOgiG9pEYsQ-eBmgkVbMDuHgPCaY',
    'TPS-ResNet-BiLSTM-Attn.pth': 'https://drive.google.com/open?id=1b59rXuGGmKne1AuHnkgDzoYgKeETNMv9',
    'TPS-ResNet-BiLSTM-CTC.pth': 'https://drive.google.com/open?id=1FocnxQzFBIjDT2F9BkNUiLdo1cC3eaO0',
}

for k, v in models.items():
  doc_id = v[v.find('=')+1:]
  # !curl -c /tmp/cookies "https://drive.google.com/uc?export=download&id=$doc_id" > /tmp/intermezzo.html
  # !curl -L -b /tmp/cookies "https://drive.google.com$(cat /tmp/intermezzo.html | grep -Po 'uc-download-link" [^>]* href="\K[^"]*' | sed 's/\&amp;/\&/g')" > $k

# !ls -al *.pth

# %%
output = !CUDA_VISIBLE_DEVICES=0 python3 demo.py \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
--image_folder demo_image/ \
--saved_model /content/drive/MyDrive/TPS-ResNet-BiLSTM-Attn.pth

# %%
from IPython.core.display import display, HTML
from PIL import Image
import base64
import io
import pandas as pd

data = pd.DataFrame()
for ind, row in enumerate(output[output.index('image_path               \tpredicted_labels         \tconfidence score')+2:]):
  row = row.split('\t')
  filename = row[0].strip()
  label = row[1].strip()
  conf = row[2].strip()
  img = Image.open(filename)
  img_buffer = io.BytesIO()
  img.save(img_buffer, format="PNG")
  imgStr = base64.b64encode(img_buffer.getvalue()).decode("utf-8") 

  data.loc[ind, 'img'] = '<img src="data:image/png;base64,{0:s}">'.format(imgStr)
  data.loc[ind, 'id'] = filename
  data.loc[ind, 'label'] = label
  data.loc[ind, 'conf'] = conf

html_all = data.to_html(escape=False)
display(HTML(html_all))

# %%
# !wget https://www.dropbox.com/sh/i39abvnefllx2si/AABX4yjNn2iLeKZh1OAwJUffa/data_lmdb_release.zip?dl=0

# %%
# before MJ, please kill process
# !unzip data_lmdb_release.zip

# %%
# !rm -rf data_lmdb_release.zip
# !rm -rf data_lmdb_release/training/MJ

# %%
# stackoverflow
# https://stackoverflow.com/questions/74289077/attributeerror-multiprocessingdataloaderiter-object-has-no-attribute-next

# %%
#@title training
# !CUDA_VISIBLE_DEVICES=0 python3 train.py \
--train_data data_lmdb_release/training --valid_data data_lmdb_release/validation \
--select_data ST --batch_ratio 1.0 \
--Transformation None --FeatureExtraction VGG --SequenceModeling BiLSTM --Prediction CTC
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: data_lmdb_release/training
# opt.select_data: ['ST']
# opt.batch_ratio: ['1.0']
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb_release/training	 dataset: ST
# sub-directory:	/ST	 num samples: 5522807
# num total samples of ST: 5522807 x 1.0 (total_data_usage_ratio) = 5522807
# num samples of ST per batch: 192 x 1.0 (batch_ratio) = 192
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# --------------------------------------------------------------------------------
# Total_batch_size: 192 = 192
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb_release/validation	 dataset: /
# sub-directory:	/.	 num samples: 6992
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 32 100 20 1 512 256 37 25 None VGG BiLSTM CTC
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=37, bias=True)
#   )
# )
# Trainable params num :  8451621
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     foreach: None
#     lr: 1
#     maximize: False
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# exp_name: None-VGG-BiLSTM-CTC-Seed1111
# train_data: data_lmdb_release/training
# valid_data: data_lmdb_release/validation
# manualSeed: 1111
# workers: 4
# batch_size: 192
# num_iter: 300000
# valInterval: 2000
# saved_model:
# FT: False
# adam: False
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: False
# select_data: ['ST']
# batch_ratio: ['1.0']
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# imgH: 32
# imgW: 100
# rgb: False
# character: 0123456789abcdefghijklmnopqrstuvwxyz
# sensitive: False
# PAD: False
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# num_gpu: 1
# num_class: 37
# ---------------------------------------
#
# [1/300000] Train loss: 25.22308, Valid loss: 8.24024, Elapsed_time: 7.29471
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# height                    |                           | 0.0000	False
# trials                    |                           | 0.0000	False
# guess                     |                           | 0.0000	False
# into                      |                           | 0.0000	False
# chingam                   |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [2000/300000] Train loss: 1.39407, Valid loss: 1.83685, Elapsed_time: 326.69197
# Current_accuracy : 21.539, Current_norm_ED  : 0.56
# Best_accuracy    : 21.539, Best_norm_ED     : 0.56
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# kaushal                   | reusaal                   | 0.0037	False
# the                       | tre                       | 0.4245	False
# marketing                 | mueteting                 | 0.0013	False
# sale                      | foe                       | 0.0106	False
# chloe                     | ciioe                     | 0.0133	False
# --------------------------------------------------------------------------------
# [4000/300000] Train loss: 0.57860, Valid loss: 1.41812, Elapsed_time: 635.93462
# Current_accuracy : 32.780, Current_norm_ED  : 0.65
# Best_accuracy    : 32.780, Best_norm_ED     : 0.65
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# for                       | for                       | 0.5846	True
# peppard                   | peoward                   | 0.0661	False
# skechers                  | sus                       | 0.0125	False
# persons                   | pers0ns                   | 0.3439	False
# com                       | com                       | 0.7944	True
# --------------------------------------------------------------------------------
# [6000/300000] Train loss: 0.47078, Valid loss: 1.31041, Elapsed_time: 943.89044
# Current_accuracy : 37.729, Current_norm_ED  : 0.68
# Best_accuracy    : 37.729, Best_norm_ED     : 0.68
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# chinese                   | chinest                   | 0.1105	False
# to                        | to                        | 0.9198	True
# foodfare                  | baade                     | 0.0002	False
# skypark                   | srvoaat                   | 0.0001	False
# zone                      | zone                      | 0.7436	True
# --------------------------------------------------------------------------------
# [8000/300000] Train loss: 0.42051, Valid loss: 1.20830, Elapsed_time: 1253.06818
# Current_accuracy : 41.905, Current_norm_ED  : 0.71
# Best_accuracy    : 41.905, Best_norm_ED     : 0.71
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ocbc                      | ocbc                      | 0.3941	True
# singtel                   | sinoen                    | 0.0583	False
# just                      | just                      | 0.9288	True
# gray                      | gny                       | 0.0398	False
# pull                      | pull                      | 0.7900	True
# --------------------------------------------------------------------------------
# [10000/300000] Train loss: 0.39039, Valid loss: 1.16476, Elapsed_time: 1560.78477
# Current_accuracy : 43.450, Current_norm_ED  : 0.72
# Best_accuracy    : 43.450, Best_norm_ED     : 0.72
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# sale                      | smm                       | 0.0070	False
# saxons                    | sakons                    | 0.0019	False
# month                     | month                     | 0.4018	True
# to                        | to                        | 0.7706	True
# starb                     | starbt                    | 0.1402	False
# --------------------------------------------------------------------------------
# [12000/300000] Train loss: 0.37060, Valid loss: 1.08541, Elapsed_time: 1868.67769
# Current_accuracy : 45.466, Current_norm_ED  : 0.74
# Best_accuracy    : 45.466, Best_norm_ED     : 0.74
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# wildlife                  | wilolire                  | 0.0453	False
# foster                    | foster                    | 0.6564	True
# resist                    | kesist                    | 0.3291	False
# any                       | any                       | 0.7520	True
# trinityleeds              | iniylasts                 | 0.0001	False
# --------------------------------------------------------------------------------
# [14000/300000] Train loss: 0.34781, Valid loss: 1.03928, Elapsed_time: 2176.50501
# Current_accuracy : 48.126, Current_norm_ED  : 0.75
# Best_accuracy    : 48.126, Best_norm_ED     : 0.75
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# warehouse                 | mameon                    | 0.0005	False
# are                       | are                       | 0.8874	True
# preferred                 | proteed                   | 0.0124	False
# to                        | to                        | 0.7406	True
# secretary                 | seeretary                 | 0.3634	False
# --------------------------------------------------------------------------------
# [16000/300000] Train loss: 0.33973, Valid loss: 1.04109, Elapsed_time: 2484.48799
# Current_accuracy : 48.756, Current_norm_ED  : 0.75
# Best_accuracy    : 48.756, Best_norm_ED     : 0.75
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# coach                     | cohct                     | 0.0257	False
# and                       | and                       | 0.9165	True
# aurora                    | aurorg                    | 0.0479	False
# tree                      | tree                      | 0.4676	True
# office                    | ohfice                    | 0.0413	False
# --------------------------------------------------------------------------------
# [18000/300000] Train loss: 0.32512, Valid loss: 1.06265, Elapsed_time: 2793.43514
# Current_accuracy : 49.013, Current_norm_ED  : 0.75
# Best_accuracy    : 49.013, Best_norm_ED     : 0.75
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 019901                    | 019907                    | 0.1637	False
# carpark                   | carpark                   | 0.2273	True
# singapore                 | sigapore                  | 0.0980	False
# sale                      | the                       | 0.0112	False
# panaso                    | panasa                    | 0.1760	False
# --------------------------------------------------------------------------------
# [20000/300000] Train loss: 0.31792, Valid loss: 0.97205, Elapsed_time: 3101.29090
# Current_accuracy : 51.301, Current_norm_ED  : 0.77
# Best_accuracy    : 51.301, Best_norm_ED     : 0.77
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# daddys                    | daddys                    | 0.5072	True
# cup                       | cun                       | 0.9263	False
# dior                      | dor                       | 0.3800	False
# off                       | off                       | 0.9610	True
# services                  | services                  | 0.9210	True
# --------------------------------------------------------------------------------
# [22000/300000] Train loss: 0.31108, Valid loss: 0.96879, Elapsed_time: 3409.88026
# Current_accuracy : 50.815, Current_norm_ED  : 0.76
# Best_accuracy    : 51.301, Best_norm_ED     : 0.77
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# finest                    | finest                    | 0.4293	True
# boonmee                   | boonmee                   | 0.1987	True
# and                       | and                       | 0.9956	True
# proven                    | proven                    | 0.2437	True
# signs                     | sions                     | 0.3073	False
# --------------------------------------------------------------------------------
# [24000/300000] Train loss: 0.30220, Valid loss: 0.94057, Elapsed_time: 3720.54415
# Current_accuracy : 52.017, Current_norm_ED  : 0.77
# Best_accuracy    : 52.017, Best_norm_ED     : 0.77
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# delicacies                | deticacians               | 0.0121	False
# bay                       | by                        | 0.3179	False
# sale                      | sale                      | 0.1875	True
# ipswich                   | ipswich                   | 0.1545	True
# rambo                     | rambo                     | 0.4467	True
# --------------------------------------------------------------------------------
# [26000/300000] Train loss: 0.29520, Valid loss: 0.95770, Elapsed_time: 4028.59057
# Current_accuracy : 51.902, Current_norm_ED  : 0.77
# Best_accuracy    : 52.017, Best_norm_ED     : 0.77
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8                         | 8                         | 0.9408	True
# levels                    | levels                    | 0.9740	True
# delicacies                | delcacis                  | 0.0026	False
# aur                       | aur                       | 0.9153	True
# customers                 | customers                 | 0.6479	True
# --------------------------------------------------------------------------------
# [28000/300000] Train loss: 0.29021, Valid loss: 0.94413, Elapsed_time: 4337.16247
# Current_accuracy : 53.547, Current_norm_ED  : 0.78
# Best_accuracy    : 53.547, Best_norm_ED     : 0.78
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# merry                     | peoay                     | 0.0024	False
# beginning                 | dag                       | 0.0005	False
# 062708                    | o6z2z0e                   | 0.0188	False
# the                       | the                       | 0.9931	True
# sale                      | gat                       | 0.0108	False
# --------------------------------------------------------------------------------
# [30000/300000] Train loss: 0.27830, Valid loss: 0.92347, Elapsed_time: 4649.81304
# Current_accuracy : 53.933, Current_norm_ED  : 0.78
# Best_accuracy    : 53.933, Best_norm_ED     : 0.78
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ipl                       | 1pl                       | 0.3867	False
# buddy                     | buddy                     | 0.7651	True
# block                     | block                     | 0.4025	True
# on                        | onn                       | 0.2187	False
# mooth                     | sneoth                    | 0.0084	False
# --------------------------------------------------------------------------------
# [32000/300000] Train loss: 0.27092, Valid loss: 0.92492, Elapsed_time: 4956.51704
# Current_accuracy : 54.548, Current_norm_ED  : 0.78
# Best_accuracy    : 54.548, Best_norm_ED     : 0.78
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# bill                      | eit                       | 0.0899	False
# chloe                     | chiot                     | 0.5866	False
# marble                    | marble                    | 0.5392	True
# geiger                    | gelear                    | 0.3853	False
# theatres                  | theatres                  | 0.7881	True
# --------------------------------------------------------------------------------
# [34000/300000] Train loss: 0.26653, Valid loss: 0.92556, Elapsed_time: 5265.55619
# Current_accuracy : 53.690, Current_norm_ED  : 0.78
# Best_accuracy    : 54.548, Best_norm_ED     : 0.78
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# good                      | good                      | 0.9754	True
# costner                   | costiner                  | 0.2110	False
# here                      | here                      | 0.6855	True
# jalan                     | jalan                     | 0.4031	True
# world                     | world                     | 0.6992	True
# --------------------------------------------------------------------------------
# [36000/300000] Train loss: 0.26634, Valid loss: 0.88255, Elapsed_time: 5574.12433
# Current_accuracy : 55.092, Current_norm_ED  : 0.79
# Best_accuracy    : 55.092, Best_norm_ED     : 0.79
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# booth                     | booth                     | 0.3261	True
# topshop                   | 1oysi0p                   | 0.0032	False
# stop                      | stop                      | 0.5295	True
# xperia                    | xperia                    | 0.4289	True
# lenovo                    | sehoe                     | 0.0083	False
# --------------------------------------------------------------------------------
# [38000/300000] Train loss: 0.26443, Valid loss: 0.92381, Elapsed_time: 5882.90940
# Current_accuracy : 54.362, Current_norm_ED  : 0.78
# Best_accuracy    : 55.092, Best_norm_ED     : 0.79
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# the                       | n                         | 0.0850	False
# centre                    | centre                    | 0.4677	True
# biersch                   | biersch                   | 0.5621	True
# breadtalk                 | beedlalk                  | 0.0089	False
# max                       | max                       | 0.8521	True
# --------------------------------------------------------------------------------
# [40000/300000] Train loss: 0.26107, Valid loss: 0.90947, Elapsed_time: 6191.30177
# Current_accuracy : 54.977, Current_norm_ED  : 0.79
# Best_accuracy    : 55.092, Best_norm_ED     : 0.79
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 372sign                   | 3172sign                  | 0.0680	False
# swan                      | swan                      | 0.6218	True
# shops                     | shops                     | 0.8565	True
# executive                 | execuive                  | 0.0596	False
# rowling                   | of                        | 0.3592	False
# --------------------------------------------------------------------------------
# [42000/300000] Train loss: 0.25827, Valid loss: 0.91032, Elapsed_time: 6500.98696
# Current_accuracy : 55.034, Current_norm_ED  : 0.79
# Best_accuracy    : 55.092, Best_norm_ED     : 0.79
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7831423                   | 13i2s                     | 0.0074	False
# live                      | live                      | 0.5729	True
# line                      | line                      | 0.9265	True
# bag                       | bag                       | 0.1810	True
# sayan                     | sayan                     | 0.8531	True
# --------------------------------------------------------------------------------
# [44000/300000] Train loss: 0.25662, Valid loss: 0.88902, Elapsed_time: 6809.99535
# Current_accuracy : 55.807, Current_norm_ED  : 0.79
# Best_accuracy    : 55.807, Best_norm_ED     : 0.79
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# your                      | your                      | 0.8779	True
# red                       | red                       | 0.7946	True
# sale                      | sale                      | 0.4127	True
# ferraby                   | ferraby                   | 0.7727	True
# promotions                | momonons                  | 0.1144	False
# --------------------------------------------------------------------------------
# [46000/300000] Train loss: 0.25509, Valid loss: 0.89051, Elapsed_time: 7119.46260
# Current_accuracy : 55.163, Current_norm_ED  : 0.79
# Best_accuracy    : 55.807, Best_norm_ED     : 0.79
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# canon                     | canon                     | 0.6607	True
# of                        | of                        | 0.9996	True
# asia                      | arn                       | 0.0664	False
# why                       | why                       | 0.5122	True
# madden                    | madden                    | 0.9600	True
# --------------------------------------------------------------------------------
# [48000/300000] Train loss: 0.25218, Valid loss: 0.88966, Elapsed_time: 7428.40765
# Current_accuracy : 55.807, Current_norm_ED  : 0.79
# Best_accuracy    : 55.807, Best_norm_ED     : 0.79
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# charts                    | charts                    | 0.4945	True
# sephora                   | sephora                   | 0.8837	True
# out                       | out                       | 0.9721	True
# sale                      | sale                      | 0.9854	True
# train                     | train                     | 0.6863	True
# --------------------------------------------------------------------------------
# [50000/300000] Train loss: 0.24680, Valid loss: 0.84854, Elapsed_time: 7737.44954
# Current_accuracy : 56.908, Current_norm_ED  : 0.80
# Best_accuracy    : 56.908, Best_norm_ED     : 0.80
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# love                      | love                      | 0.8872	True
# mission                   | mission                   | 0.7274	True
# an                        | an                        | 0.9611	True
# weve                      | weve                      | 0.4750	True
# platform                  | platform                  | 0.5400	True
# --------------------------------------------------------------------------------
# [52000/300000] Train loss: 0.24840, Valid loss: 0.85935, Elapsed_time: 8045.27072
# Current_accuracy : 56.264, Current_norm_ED  : 0.79
# Best_accuracy    : 56.908, Best_norm_ED     : 0.80
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# tops                      | tops                      | 0.9437	True
# smoking                   | smoking                   | 0.5223	True
# coast                     | eaast                     | 0.6120	False
# office                    | office                    | 0.2835	True
# reading                   | reading                   | 0.4140	True
# --------------------------------------------------------------------------------
# [54000/300000] Train loss: 0.24866, Valid loss: 0.83577, Elapsed_time: 8354.09998
# Current_accuracy : 56.994, Current_norm_ED  : 0.80
# Best_accuracy    : 56.994, Best_norm_ED     : 0.80
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# road                      | road                      | 0.8388	True
# the                       | the                       | 0.8598	True
# rumah                     | rumah                     | 0.6556	True
# dior                      | dior                      | 0.9001	True
# state                     | state                     | 0.8673	True
# --------------------------------------------------------------------------------
# [56000/300000] Train loss: 0.24366, Valid loss: 0.86179, Elapsed_time: 8662.27411
# Current_accuracy : 55.993, Current_norm_ED  : 0.80
# Best_accuracy    : 56.994, Best_norm_ED     : 0.80
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# love                      | love                      | 0.8229	True
# coffee                    | corrte                    | 0.1891	False
# yds                       | yds                       | 0.4129	True
# mrbt                      | mupnud                    | 0.0007	False
# living                    | living                    | 0.9057	True
# --------------------------------------------------------------------------------
# [58000/300000] Train loss: 0.23777, Valid loss: 0.83336, Elapsed_time: 8972.46221
# Current_accuracy : 57.366, Current_norm_ED  : 0.80
# Best_accuracy    : 57.366, Best_norm_ED     : 0.80
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# syncmaster                | syncmaster                | 0.1799	True
# sale                      | sale                      | 0.9030	True
# way                       | way                       | 0.9647	True
# inception                 | nebler                    | 0.0011	False
# furniture                 | rumre                     | 0.0204	False
# --------------------------------------------------------------------------------
# [60000/300000] Train loss: 0.22432, Valid loss: 0.81100, Elapsed_time: 9278.10013
# Current_accuracy : 57.909, Current_norm_ED  : 0.81
# Best_accuracy    : 57.909, Best_norm_ED     : 0.81
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# serves                    | serves                    | 0.2575	True
# more                      | more                      | 0.4438	True
# made                      | made                      | 0.6311	True
# shop                      | shop                      | 0.7348	True
# albert                    | albert                    | 0.4079	True
# --------------------------------------------------------------------------------
# [62000/300000] Train loss: 0.22409, Valid loss: 0.84822, Elapsed_time: 9586.90915
# Current_accuracy : 56.307, Current_norm_ED  : 0.79
# Best_accuracy    : 57.909, Best_norm_ED     : 0.81
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# loans                     | loans                     | 0.9208	True
# your                      | your                      | 0.7601	True
# beauty                    | beaulty                   | 0.1928	False
# cctv                      | cry                       | 0.4074	False
# hol                       | hol                       | 0.9670	True
# --------------------------------------------------------------------------------
# [64000/300000] Train loss: 0.22426, Valid loss: 0.84289, Elapsed_time: 9895.38966
# Current_accuracy : 57.323, Current_norm_ED  : 0.80
# Best_accuracy    : 57.909, Best_norm_ED     : 0.81
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# garden                    | garden                    | 0.9610	True
# vacheron                  | macheron                  | 0.0958	False
# silkworm                  | a                         | 0.0409	False
# dogs                      | dogs                      | 0.9456	True
# raised                    | raised                    | 0.5476	True
# --------------------------------------------------------------------------------
# [66000/300000] Train loss: 0.22284, Valid loss: 0.85196, Elapsed_time: 10203.93088
# Current_accuracy : 58.095, Current_norm_ED  : 0.80
# Best_accuracy    : 58.095, Best_norm_ED     : 0.81
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# hermes                    | herises                   | 0.0115	False
# donuts                    | donuts                    | 0.4964	True
# lifestyle                 | unesmue                   | 0.0786	False
# colectpoint               | oteepoint                 | 0.0000	False
# sale                      | sale                      | 0.6858	True
# --------------------------------------------------------------------------------

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 train.py \
--train_data data_lmdb_release/training --valid_data data_lmdb_release/validation \
--select_data MJ-ST --batch_ratio 0.5-0.5 \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn
