# %% [markdown]
# <a href="https://colab.research.google.com/github/softmurata/colab_notebooks/blob/main/audio/vall_e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python3.10 install
# !wget https://github.com/korakot/kora/releases/download/v0.10/py310.sh
# !bash ./py310.sh -b -f -p /usr/local
# !python -m ipykernel install --name "py310" --user

# %%
# !pip --version

# %%
# !git clone --recursive https://github.com/enhuiz/vall-e.git

# %%
# !pip install git+https://github.com/enhuiz/vall-e

# %%
import os
os.chdir("/content/vall-e")

# %%
# !ls
# Out:
# config	LICENSE    requirements.txt  setup.py  vall-e.png
# data	README.md  scripts	     vall_e

# %%
# quantize
# !python -m vall_e.emb.qnt data/test
# Out:
# 100% 4/4 [00:00<00:00, 32326.04it/s]

# %%
# Generate phonemes based on the text
# !python -m vall_e.emb.g2p data/test
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# 100% 1/1 [00:00<00:00,  1.31it/s]

# %%
# train
# !python -m vall_e.train yaml=config/test/ar.yml
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   "wall_time": 1673595467.1628816,
#   "global_step": 254502
# }
# 2023-01-13 07:37:47 - vall_e.utils.trainer - INFO - GR=0;LR=0 -
# New epoch starts.
# 2023-01-13 07:37:47 - vall_e.data - INFO - GR=0;LR=0 -
# Failed to find another different utterance for test, using the same audio as prompt.
# [2023-01-13 07:37:47,231] [INFO] [timer.py:197:stop] 0/254503, RunningAvgSamplesPerSec=15.845584451839239, CurrSamplesPerSec=15.889922715562964, MemAllocated=0.19GB, MaxMemAllocated=0.27GB
# 2023-01-13 07:37:47 - vall_e.utils.trainer - INFO - GR=0;LR=0 -
# {
#   "model.loss": 3.8146968917018853e-10,
#   "model.lr": 0.00014950260460460461,
#   "model.grad_norm": 9.04308663507436e-08,
#   "model.elapsed_time": 0.06342601776123047,
#   "model.engine_step": 254503,
#   "model.loss.nll": 3.8146968917018853e-10,
#   "elapsed_time": 0.06342601776123047,
#   "wall_time": 1673595467.2328334,
#   "global_step": 254503
# }
# ...
