# %% [markdown]
# <a href="https://colab.research.google.com/github/softmurata/colab_notebooks/blob/main/audio/tangottszenn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installation

# %%
# !git clone https://github.com/declare-lab/tango/
# %cd tango
# !pip install transformers==4.27.0 accelerate==0.18.0 datasets==2.1.0 einops==0.6.1 h5py==3.8.0 huggingface_hub==0.13.3 importlib_metadata==6.3.0 omegaconf==2.3.0 packaging==23.1 progressbar33==2.4 protobuf==3.20.* resampy==0.4.2 soundfile==0.12.1 ssr_eval==0.0.6 torchlibrosa==0.1.0 librosa==0.9.2
# %cd diffusers
# !pip install -e .

# %%
# before start inference, please make /content/tango/predict.py and copy the following script
"""
import argparse
import soundfile as sf
from tango import Tango

parser = argparse.ArgumentParser()
parser.add_argument("--prompt", type=str, default="An audience cheering and clapping")
parser.add_argument("--samplerate", type=int, default=16000)
args = parser.parse_args(args=[])

tango_model = Tango("declare-lab/tango")
prompt = args.prompt
audio = tango_model.generate(prompt)
# save audio for wav format
sf.write(f"{prompt}.wav", audio, samplerate=args.samplerate)

print(f"{prompt}.wav")

"""

# %% [markdown]
# Inference

# %%
# %cd /content/tango

# %%
# !python predict.py

# %%
import IPython
# display Audio
IPython.display.Audio("An audience cheering and clapping.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Advanced inference

# %% [markdown]
# 日本語対応

# %%
# !pip install transformers sentencepiece

# %%
# before start inference, please make /content/tango/predict_jp_pipeline.py and copy the following script
"""
import soundfile as sf
from tango import Tango
from transformers import pipeline

# load model
je_translator = pipeline("translation", model="staka/fugumt-ja-en")
tango_model = Tango("declare-lab/tango")

# create english prompt
text = "観客が手を叩いて拍手する"
response = je_translator(text)
prompt = response[0]["translation_text"]

audio = tango_model.generate(prompt)
# save audio for wav format
sf.write("japanese.wav", audio, samplerate=16000)
"""

# %%
# %cd /content/tango

# %%
# please change text in predict_jp_pipeline.py
# !python predict_jp_pipeline.py

# %%
import IPython
# display Audio
IPython.display.Audio("japanese.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
