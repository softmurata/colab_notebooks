# %% [markdown]
# <a href="https://colab.research.google.com/github/softmurata/colab_notebooks/blob/main/audio/coqitts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installation

# %%
# !pip install -q TTS

# %%
# !pip install -q cutlet
# !pip install -q unidic-lite

# %%
import torch
from TTS.api import TTS

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
print(TTS().list_models())

# Init TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v1.1").to(device)

# %%
import fugashi
fugashi.Tagger()

# %%
# Run TTS
# ❗ Since this model is multi-lingual voice cloning model, we must set the target speaker_wav and language
# Text to speech list of amplitude values as output
wav = tts.tts(text="こんにちは", speaker_wav="/content/anmarimuzukashiku_01.wav", language="ja")
# Text to speech to a file
# tts.tts_to_file(text="Hello world!", speaker_wav="/content/001-sibutomo.mp3", language="ja", file_path="output.wav")

# %%
tts.tts_to_file(text="こんにちは、今日もいい天気ですね。", speaker_wav="/content/anmarimuzukashiku_01.wav", language="ja", file_path="/content/output.wav")

# %%
# 中国人が日本語話しているみたいww
from IPython.display import Audio, display

display(Audio("/content/output.wav", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Tips

# %%
# !ffmpeg -i "/content/001-sibutomo.mp3" -vn -ac 2 -ar 44100 -acodec pcm_s16le -f wav "/contnet/001-sibutomo.wav"
