# %% [markdown]
# <a href="https://colab.research.google.com/github/softmurata/colab_notebooks/blob/main/nlp/gpt2_finetuning_eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
#@title fine-tuning gpt neo

# %%
# 綺麗な画像を生成するために使われたpromptとその映像のリンク等のメタデータを保存してあるcsvファイル
# !wget -O prompts.csv https://raw.githubusercontent.com/krea-ai/open-prompts/main/data/1k.csv

# %%
import pandas as pd

# %%
prompts = pd.read_csv("prompts.csv")

# %%
prompts.head()

# %%
prompts_gt6 = prompts.loc[prompts.prompt.str.split(' ').str.len() > 6]
prompts_gt6.head()

# %%
# downgrade for aitextgen
# !pip install git+https://github.com/llimllib/aitextgen@fix_tpu_available
# !pip uninstall -qqy torch torchvision torchtext torchaudio fastai
# !pip install -qq torch==1.9.0 pytorch-lightning==1.7.7 aitextgen==0.6.0

# %%
model_name = "EleutherAI/gpt-neo-125M"

# %%
# delete raw data
prompts_gt6 = prompts_gt6.drop('raw_data', axis = 1).reset_index(drop=True)

# %%
prompts_gt6.to_csv("input_text_cleaned.txt", columns=["prompt"], header=False, index=False)

# %%
import pytorch_lightning as pl
print(pl.__version__)

# %%
from aitextgen.TokenDataset import TokenDataset
data = TokenDataset('./input_text_cleaned.txt', line_by_line=True)

# %%
from aitextgen import aitextgen
ai = aitextgen(model = model_name,  to_gpu=True)

# %%
ai.train('input_text_cleaned.txt',
         line_by_line=True,
         from_cache=False,
         num_steps=500,
         generate_every=100,
         save_every=500,
         save_gdrive=False,
         learning_rate=1e-3,
         fp16=False,
         batch_size=1, 
         )

# %%
ai.save()

# %%
prompt_ai = aitextgen(model_folder = '.', to_gpu=True)

# %%
print(prompt_ai.generate(prompt = "astronaut "))

# %%
#@title upload hugging face hub

# %%
ai.save_for_upload('sd-prompt-generator-gpt-neo')

# %%
# Please create huggingface access token with write right by huggingface web ui
from huggingface_hub import notebook_login

notebook_login()

# %%
# !sudo apt-get install git-lfs

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
api.upload_folder(
    folder_path="./sd-prompt-generator-gpt-neo",
    path_in_repo = ".",
    repo_id="mutatasu/sd-prompt-generator-gpt-neo",
    repo_type="model"
)

# %%
#@title gpt2 finetuning
# https://www.ai-shift.co.jp/techblog/3170

# %%
# !nvidia-smi

# %%
# test data
# !wget https://instruct-pix2pix.eecs.berkeley.edu/human-written-prompts.jsonl

# %%
# !pip install sentencepiece transformers

# %%
# !mkdir myoutputs

# %%
import json
import logging
import os
import random
import sys
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
from torch.optim import AdamW
from tqdm import tqdm
from transformers import AutoConfig, AutoTokenizer, AutoModelForCausalLM
from transformers import T5Tokenizer

seed = 42
train_file = 'human-written-prompts.jsonl'
eval_file = 'human-written-prompts.jsonl'
eval_out_file = 'myoutputs/out.txt'
output_dir = 'myoutputs'
num_train_epochs = 1
n_prompt_tokens = 200
train_batch_size = 2
learning_rate = 3e-4
max_new_tokens = 10
model_name =  "gpt2"

# %%
class PromptTuningLM(nn.Module):
    def __init__(
        self,
        model_name: str,
        n_prompt_tokens: int,
        config: AutoConfig,
        soft_prompt_path: str = None,
    ):
        super(PromptTuningLM, self).__init__()
        self.n_prompt_tokens = n_prompt_tokens 
        # 事前学習済みのGPTの呼び出し
        self.lm = AutoModelForCausalLM.from_pretrained(model_name, config=config)
        # Promptに対する埋め込みベクトルの作成
        self.soft_prompt = nn.Embedding(n_prompt_tokens, config.hidden_size)
        torch.nn.init.xavier_uniform_(self.soft_prompt.weight)

        # GPTの重みを固定
        for param in self.lm.parameters():
            param.requires_grad = False

        # [推論時] Promptに対する学習済みの埋め込みベクトルをロード
        if soft_prompt_path is not None: 
            logger.info(f"Set soft prompt. ({n_prompt_tokens} tokens)")
            self.soft_prompt = torch.load(soft_prompt_path)

    def _extend_inputs(self, input_ids) -> torch.Tensor:
        """
        Promptに対する埋め込みベクトルを付与する
        """
        # input_idsをベクトルに変換する（事前学習モデルが異なる場合は変更する必要あり）
        inputs_embeds = self.lm.transformer.wte(input_ids)
        if len(list(inputs_embeds.shape)) == 2:
            inputs_embeds = inputs_embeds.unsqueeze(0)
        # Promptに対する埋め込みベクトルとinputs_embedsを連結する
        batch_size = inputs_embeds.size(0)
        learned_embeds = self.soft_prompt.weight.repeat(batch_size, 1, 1)
        extended_embeds = torch.cat([learned_embeds, inputs_embeds], dim=1)
        return extended_embeds

    def _extend_labels(self, labels, ignore_index=-100) -> torch.Tensor:
        """
        inputに合わせて正解ラベルにPromptに対するラベルを付与する
        """
        if len(list(labels.shape)) == 1:
            labels = labels.unsqueeze(0)
        n_batches = labels.shape[0]
        # Promptに対してignore_indexを付与（-100に設定していれば損失が計算されない）
        prompt_labels = torch.full((n_batches, self.n_prompt_tokens), 
                                    ignore_index).to(labels.device)
        # Promptに対するラベルと元の正解ラベルを連結する
        extended_labels = torch.cat([prompt_labels, labels], dim=1)
        return extended_labels

    def save_soft_prompt(self, path: str, filename: str):
        """
        Promptに対する埋め込みベクトルの保存
        """
        torch.save(self.soft_prompt, os.path.join(path, filename))
        logger.info(f"Saved soft prompt: {os.path.join(path, filename)}")

    def forward(self, input_ids, labels=None, return_dict=None):
        # Promptを付与したベクトル
        inputs_embeds = self._extend_inputs(input_ids)
        if labels is not None:
            labels = self._extend_labels(labels)

        return self.lm(
            inputs_embeds=inputs_embeds,
            labels=labels,
            return_dict=return_dict,
        )

    def generate(self, input_text, tokenizer, max_new_tokens, eos_token_id, device):
        """
        [推論時]自己回帰で回答を生成する
        """
        input_ids = tokenizer.encode(input_text, add_special_tokens=False)
        cur_ids = torch.tensor(input_ids).unsqueeze(0).to(device)
        # 最大でmax_new_tokensだけ単語を生成する
        for _ in range(max_new_tokens):
            outputs = self.forward(cur_ids)
            softmax_logits = torch.softmax(outputs.logits[0,-1], dim=0)
            # 最大確率の単語を次の単語として一意に決定
            next_token_id = int(softmax_logits.argmax().to('cpu'))
            # もし選択された単語がeos_tokenなら生成を終了する
            if next_token_id == eos_token_id:
                break
            # 選択された単語をcur_idsに追加して次の処理を行う
            next_token_id = torch.tensor([[next_token_id]]).to(device)
            cur_ids = torch.cat([cur_ids, next_token_id], dim=1)

        # 生成した単語ID列をテキストに変換する
        output_list = list(cur_ids.squeeze().to('cpu').numpy())
        output_text = tokenizer.decode(output_list)
        return output_text

# %%
logging.basicConfig(level=logging.INFO, stream=sys.stdout)
logger = logging.getLogger(__name__)

os.makedirs(output_dir, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if n_gpu > 0:
    torch.cuda.manual_seed_all(seed)

# tokenizer = T5Tokenizer.from_pretrained(model_name)  # for japanese
tokenizer = AutoTokenizer.from_pretrained(model_name)
config = AutoConfig.from_pretrained(model_name)
model = PromptTuningLM(
    model_name,
    n_prompt_tokens=n_prompt_tokens,
    config=config,
)

model.to(device)

# LayerNorm.{weight, bias}に対してweight_decay=0.01を設定
param_optimizer = list(model.named_parameters())
optimizer_grouped_parameters = [
    {'params': [p for n, p in param_optimizer if not ('ln' in n)],
     'weight_decay': 0.01},
    {'params': [p for n, p in param_optimizer if 'ln' in n],
     'weight_decay': 0.0}
]
optimizer = AdamW(optimizer_grouped_parameters, lr=learning_rate)

# %%
@dataclass
class InputExample():
    input: str
    edit: str
    output: str

def create_examples(filename):
    examples = []
    with open(filename, 'r') as f:
        for line in f:
            example = json.loads(line)
            examples.append(InputExample(
                input = example['input'],
                edit = example['edit'],
                output = example['output']))
    return examples

"""
class CustomDataset(torch.utils.data.IterableDataset):
    def __init__(self, tokenizer, input_generator, output_generator):
        super().__init__()
        self._tokenizer = tokenizer
        self._input_generator = input_generator
        self._output_generator = output_generator

    @classmethod
    def from_texts(cls, tokenizer, input_texts, output_texts):
        return cls(tokenizer=tokenizer, input_generator=lambda: input_texts, 
                   output_generator=lambda: output_texts)

    def __iter__(self):
        for text in self._generator():
            ids = self._tokenizer.encode(text)
            yield {"input_ids": ids, "labels": ids}
"""

from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, tokenizer, input_texts, output_texts):
      super().__init__()
      self._tokenizer = tokenizer
      self._input_texts = input_texts
      self._output_texts = output_texts
    def __getitem__(self, index):
        input_ids = self._tokenizer.encode(self._input_texts[index])
        output_ids = self._tokenizer.encode(self._output_texts[index])
        return {"input_ids": input_ids, "labels": output_ids}

    def __len__(self):
        return len(self._input_texts)

def collate_fn(samples):
    batch = {'input_ids': [], 'labels': []}
    for sample in samples:
        batch['input_ids'].append(torch.tensor(sample['input_ids']))
        batch['labels'].append(torch.tensor(sample['labels']))
    batch['input_ids'] = torch.nn.utils.rnn.pad_sequence(
                    batch['input_ids'], batch_first=True, padding_value=3)
    batch['labels'] = torch.nn.utils.rnn.pad_sequence(
                    batch['labels'], batch_first=True, padding_value=3)
    return batch

# %%
tokenizer.special_tokens_map
# Out:
# {'bos_token': '<|endoftext|>',
#  'eos_token': '<|endoftext|>',
#  'unk_token': '<|endoftext|>'}

# %%
import torch

# %%
logger.info("***** Running training *****")
train_examples = create_examples(train_file)
train_input_texts = [example.input + "+" + example.edit
                for example in train_examples]
train_output_texts = ["="+example.output for example in train_examples]
train_data = CustomDataset(tokenizer, train_input_texts, train_output_texts)
train_dataloader = torch.utils.data.DataLoader(dataset=train_data,
                    batch_size=train_batch_size, collate_fn=collate_fn)

model.train()
num_train_epochs = 2
for epoch in range(int(num_train_epochs)):
    logger.info(f'Epoch: {epoch+1}')
    for batch in tqdm(train_dataloader):
        input_ids = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)
        print(input_ids.shape, labels.shape)  # need to same shape input and labels?
        outputs = model(input_ids, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

# Promptに対する埋め込みベクトルのみ保存する
model_to_save = model.module if hasattr(model, 'module') else model
model_to_save.save_soft_prompt(output_dir, 'soft_prompt.pt')
# Out:
#   0%|          | 0/350 [00:00<?, ?it/s]
# torch.Size([2, 33]) torch.Size([2, 29])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-a207b7d61847> in <module>
#      16         labels = batch['labels'].to(device)
#      17         print(input_ids.shape, labels.shape)
# ---> 18         outputs = model(input_ids, labels=labels)
#      19         loss = outputs.loss
#      20         loss.backward()
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-2-091971c6f35c> in forward(self, input_ids, labels, return_dict)
#      65             labels = self._extend_labels(labels)
#      66
# ---> 67         return self.lm(
#      68             inputs_embeds=inputs_embeds,
#      69             labels=labels,
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1072             # Flatten the tokens
#    1073             loss_fct = CrossEntropyLoss()
# -> 1074             loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))
#    1075
#    1076         if not return_dict:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#    1172
#    1173     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1174         return F.cross_entropy(input, target, weight=self.weight,
#    1175                                ignore_index=self.ignore_index, reduction=self.reduction,
#    1176                                label_smoothing=self.label_smoothing)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3024     if size_average is not None or reduce is not None:
#    3025         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3026     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#    3027
#    3028
#
# ValueError: Expected input batch_size (464) to match target batch_size (456).

# %%
#@title inference
logger.info("***** Running evaluation *****")
tokenizer = AutoTokenizer.from_pretrained(model_name)
config = AutoConfig.from_pretrained(model_name)
model = PromptTuningLM(
    model_name,
    n_prompt_tokens=n_prompt_tokens,
    soft_prompt_path=os.path.join(output_dir, 'soft_prompt.pt'),
    config=config,
)
model.to(device)
model.eval()
output_texts = []

with open(eval_file, 'r') as f:
    for line in f:
        data = json.loads(line)
        input_text = data['input'] + "+" + data["edit"]
        output_text = model.generate(input_text, tokenizer,
                        max_new_tokens, tokenizer.eos_token_id, device)
        
        print("input_text:", input_text, "  output_text:", output_text)
        output_texts.append(output_text+'\n')
with open(eval_out_file, 'w') as f:
    f.writelines(output_texts)
# Out:
# input_text: Summer Street With Blooming Flowers (PRT_1003) - Canvas Art Print - 25in X 20in+Change it to mexican muralism./   output_text: Summer Street With Blooming Flowers (PRT_1003) - Canvas Art Print - 25in X 20in+Change it to mexican muralism./$1.00$1.00$1
# input_text: rainforest Jaguar by Lisa McLaughlin+Turn the Jaguar into a lizard/   output_text: rainforest Jaguar by Lisa McLaughlin+Turn the Jaguar into a lizard/dragon/dragon/dragon/dragon/dragon/
# input_text: Frog in a Flower Pot - Image 0+make the frog purple/   output_text: Frog in a Flower Pot - Image 0+make the frog purple/green/blue/yellow/purple/yellow
# input_text: Autumn colors framed by traditional Japanese sliding doors and tatami mats+Make it an Ukiyo-e painting/   output_text: Autumn colors framed by traditional Japanese sliding doors and tatami mats+Make it an Ukiyo-e painting/museum+Make it an Ukiyo-
# input_text: Anime girl with short pink hair | Drawing 15 | Pinterest+as a medieval illustrated manuscript./   output_text: Anime girl with short pink hair | Drawing 15 | Pinterest+as a medieval illustrated manuscript./Photograph by: J.M.S.
# input_text: Share with me your wallpaper Here's mine. - Humor Photo - Humor images - Share with me your wallpaper Here& mine. The post Share with me your wallpaper Here& mine. appeared first on Gag Dad. Cyberpunk City, Cyberpunk Aesthetic, City Aesthetic, Anime Scenery Wallpaper, City Wallpaper, Iphone Wallpaper, Anime Wallpapers Iphone, Future Wallpaper, Japon Illustration+Make it rococo/   output_text: Share with me your wallpaper Here's mine. - Humor Photo - Humor images - Share with me your wallpaper Here& mine. The post Share with me your wallpaper Here& mine. appeared first on Gag Dad. Cyberpunk City, Cyberpunk Aesthetic, City Aesthetic, Anime Scenery Wallpaper, City Wallpaper, Iphone Wallpaper, Anime Wallpapers Iphone, Future Wallpaper, Japon Illustration+Make it rococo/pixy/pixy/pix
# input_text: Painted World of Ariandel+More Rennaissance./   output_text: Painted World of Ariandel+More Rennaissance./Painted World of Ariandel+More Renna
# input_text: Reading by the Lamp by Delphin Enjolras via yarnstorm+move outside/   output_text: Reading by the Lamp by Delphin Enjolras via yarnstorm+move outside/inside/outside of the house. The house is
# input_text: Black-bellied Hummingbird, Costa Rica+swap with Eagle/   output_text: Black-bellied Hummingbird, Costa Rica+swap with Eagle/Crowned Hummingbird, Costa Rica+
# input_text: Yefim Volkov, Misty Morning+make it afternoon/   output_text: Yefim Volkov, Misty Morning+make it afternoon/night, and then go to the bathroom. You
# input_text: fortification: Fortification on the Ganges during the sunset. Stock Photo+As pop art./   output_text: fortification: Fortification on the Ganges during the sunset. Stock Photo+As pop art./Photographer: Robert H. H. H.
# input_text: geiranger norway small village nighttime wallpaper+turn into a campsite/   output_text: geiranger norway small village nighttime wallpaper+turn into a campsite/campfire+turn into a campfire+turn
# input_text: Woody's Lunch Box Revealed as Food Location in Toy Story Land+make the lunchbox gold/   output_text: Woody's Lunch Box Revealed as Food Location in Toy Story Land+make the lunchbox gold/silver/gold/silver/gold/silver/
# input_text: girl with horse at sunset+change the background to a city/   output_text: girl with horse at sunset+change the background to a city/town+change the background to a city/town
# input_text: June Carey-California Wine Country+More expressionist./   output_text: June Carey-California Wine Country+More expressionist./More expressionist./More expressionist./More expression
# input_text: hillsborough, river, state park, sun rays, rapids, morning, atmosphere, awarded, florida, south florida, nature, photography, UFHEALTH+Inject some surrealism/   output_text: hillsborough, river, state park, sun rays, rapids, morning, atmosphere, awarded, florida, south florida, nature, photography, UFHEALTH+Inject some surrealism/artistic art into your life. You will be
# input_text: Brigid is a well-known Irish Celtic Goddess who enjoys candle-flame as an offering.+Make baroque./   output_text: Brigid is a well-known Irish Celtic Goddess who enjoys candle-flame as an offering.+Make baroque./Make candle-flame candle-flame candle-flame
# input_text: """N45"" - Thiago Moura Januário, 2015 {figurative art female head black woman face portrait digital grunge cropped painting #loveart} userthiago.deviantart.com"+give her freckles/   output_text: """N45"" - Thiago Moura Januário, 2015 {figurative art female head black woman face portrait digital grunge cropped painting #loveart} userthiago.deviantart.com"+give her freckles/paintings/n45"+"N
# input_text: elizabeth taylor died famous americans who died in 2011 a knowledge archive+Cubism./   output_text: elizabeth taylor died famous americans who died in 2011 a knowledge archive+Cubism./Cubism/Cubism/Cubism/Cub
# input_text: The arrest of Louis XVI and his family.+as a Pixar movie/   output_text: The arrest of Louis XVI and his family.+as a Pixar movie/TV series.+as a Disney movie/TV
# input_text: The Église Saint-Nizier (St. Nizier Church) is a Flamboyant Gothic church built during the 14th and 15th centuries. Located at the heart of the Presqu'île, this church was originally erected in memory of the early Christian martyrs of Lyon.+Fauvism painting./   output_text: The Église Saint-Nizier (St. Nizier Church) is a Flamboyant Gothic church built during the 14th and 15th centuries. Located at the heart of the Presqu'île, this church was originally erected in memory of the early Christian martyrs of Lyon.+Fauvism painting./Fauvism painting.+Fauv
# input_text: City in the clouds speedpaint by Tryingtofly+by Lisa Frank/   output_text: City in the clouds speedpaint by Tryingtofly+by Lisa Frank/Flickr Creative Commons Attribution-ShareAlike 3.
# input_text: Assassin s Creed Syndicate 1+as a pencil sketch/   output_text: Assassin s Creed Syndicate 1+as a pencil sketch/drawing/painting/painting/pain
# input_text: Panoramic Milky Way over the observatory+As a Basquiat painting/   output_text: Panoramic Milky Way over the observatory+As a Basquiat painting/photograph of the Milky Way+As a Bas
# input_text: Panoramic view of famous Le Mont Saint-Michel tidal island in beautiful twilight during blue hour at dusk, Normandy, northern France+have it be during the end of the world/   output_text: Panoramic view of famous Le Mont Saint-Michel tidal island in beautiful twilight during blue hour at dusk, Normandy, northern France+have it be during the end of the world/nightmare of the sea+the sea is the
# input_text: Old Hollywood Stars, Hollywood Icons, Old Hollywood Glamour, Golden Age Of Hollywood, Vintage Hollywood, Hollywood Actresses, Classic Hollywood, Old Hollywood Makeup, Lauren Bacall+turn into caricature drawings/   output_text: Old Hollywood Stars, Hollywood Icons, Old Hollywood Glamour, Golden Age Of Hollywood, Vintage Hollywood, Hollywood Actresses, Classic Hollywood, Old Hollywood Makeup, Lauren Bacall+turn into caricature drawings/artwork, Hollywood Icons, Hollywood Icons
# input_text: Kanojo Okarishimasu Rent A Girlfriend Zerochan Anime Image Board+Increase realism/   output_text: Kanojo Okarishimasu Rent A Girlfriend Zerochan Anime Image Board+Increase realism/artistic quality+Increase realism/artistic quality
# input_text: Painting of The Flying Scotsman train at York station+add airplane wings/   output_text: Painting of The Flying Scotsman train at York station+add airplane wings/wings+add airplane wings/wings+add airplane
# input_text: Fashions in Tones of Green+More like an illustration by Hayao Miyazaki/   output_text: Fashions in Tones of Green+More like an illustration by Hayao Miyazaki/Shutterstock.com/Shutterstock.com/
# input_text: Astronomy Photographer of the Year 2013 | OntarioStargazing Astro Highlights | Scoop.it+In the style of Pablo Picasso./   output_text: Astronomy Photographer of the Year 2013 | OntarioStargazing Astro Highlights | Scoop.it+In the style of Pablo Picasso./Photographer of the Year 2013 | OntarioStarg
# input_text: Puzzle (1000pc) Terry Redlin : Our Friends+make the people wear top hats/   output_text: Puzzle (1000pc) Terry Redlin : Our Friends+make the people wear top hats/tights/etc.
#
# : Our Friends
# input_text: wide-tomorrowland-movie-2015-wallpaper.jpg+By Gustav Klimt./   output_text: wide-tomorrowland-movie-2015-wallpaper.jpg+By Gustav Klimt./Photographer: Gustav Klimt./Photographer
# input_text: The natural reserve of Pian di Spagna flooded with snowy peaks reflected in the water, Valtellina, Lombardy, Italy, Europe+More like a Vincent Van Gogh painting/   output_text: The natural reserve of Pian di Spagna flooded with snowy peaks reflected in the water, Valtellina, Lombardy, Italy, Europe+More like a Vincent Van Gogh painting/photography. The natural reserve of Pian di
# input_text: Waterfall in the autumn photo+As if it were by Andy Warhol./   output_text: Waterfall in the autumn photo+As if it were by Andy Warhol./Photographer: Andy Warhol/Photographer:
# input_text: Mount Fuji by Michael Creese+change the artist to Salvador Dali/   output_text: Mount Fuji by Michael Creese+change the artist to Salvador Dali/Dali +change the artist to Salvador Dali
# input_text: FIRST STRIKE ON BERLIN by Nicolas Trudgian with 100th Bomb Group Veterans+swap BERLIN for THE NORTH POLE/   output_text: FIRST STRIKE ON BERLIN by Nicolas Trudgian with 100th Bomb Group Veterans+swap BERLIN for THE NORTH POLE/BELLEFORD. The BERLIN
# input_text: Photographer Captures Soulful Portraits Of Dogs In Austrian Wilderness #dog #animals #photography #portrait+turn the dogs into babies/   output_text: Photographer Captures Soulful Portraits Of Dogs In Austrian Wilderness #dog #animals #photography #portrait+turn the dogs into babies/children+make them feel like babies+make them
# input_text: Abandoned spiral staircases and staircases on pinterest for Victorian spiral staircase+More like a Jackson Pollock painting./   output_text: Abandoned spiral staircases and staircases on pinterest for Victorian spiral staircase+More like a Jackson Pollock painting./Abandoned spiral staircases and staircases on
# input_text: First Light at Lake Louise pastel by Carla J Griffin+As if it were trending on artstation/   output_text: First Light at Lake Louise pastel by Carla J Griffin+As if it were trending on artstation/artstation/artstation/artstation/art
# input_text: Red-hair-beauty-photography+In the style of Vermeer./   output_text: Red-hair-beauty-photography+In the style of Vermeer./The style of Vermeer. The style of
# input_text: Carole Lombard - by George Hurrell 1937+put a crown on her head/   output_text: Carole Lombard - by George Hurrell 1937+put a crown on her head/head/head/head/head/head/
# input_text: Look over a hill landscape with two women at a table.+As a painting by Paul Gauguin./   output_text: Look over a hill landscape with two women at a table.+As a painting by Paul Gauguin./Photograph by Paul Gauguin.
# input_text: Joan Crawford - joan-crawford Photo+make it look like a Wooden Carving/   output_text: Joan Crawford - joan-crawford Photo+make it look like a Wooden Carving/Carpet Painting/Carpet Painting/
# input_text: Russian Artist Recreates <i>Futurama</i> Skyline in 3D+As if it were by Joan Miro./   output_text: Russian Artist Recreates <i>Futurama</i> Skyline in 3D+As if it were by Joan Miro./Photographer: <i>Futurama
# input_text: In her kitchen lined with head vases, Von Teese serves cookies and tea in a vintage teapot. Photo by Douglas Friedman.+change to a Normal Rockwel painting/   output_text: In her kitchen lined with head vases, Von Teese serves cookies and tea in a vintage teapot. Photo by Douglas Friedman.+change to a Normal Rockwel painting/photo by Douglas Friedman.+change to a Normal
# input_text: Temple in the Snow+As a Clara Peeters painting./   output_text: Temple in the Snow+As a Clara Peeters painting./The Snow+As a Clara Peeters painting./
# input_text: Tagonoura no Yuu    (Mt. Fuji seen from Tagonoura, Evening)+make it an erupting volcano/   output_text: Tagonoura no Yuu    (Mt. Fuji seen from Tagonoura, Evening)+make it an erupting volcano/firestorm/firestorm/firestorm/fire
# input_text: Grace Kelly Hairstyles+More like a Hubert Robert painting./   output_text: Grace Kelly Hairstyles+More like a Hubert Robert painting./Photographer: Michael J. Schoenfeld/
# input_text: Portrait of beautiful girl with red lips and blue eyes+As if it were by John Atkinson Grimshaw/   output_text: Portrait of beautiful girl with red lips and blue eyes+As if it were by John Atkinson Grimshaw/The New York Times/Getty Images+The New
# input_text: Afternoon at Pass Cre... by  Robert E. Wood - Masterpiece Online+by Peter Mohrbacher/   output_text: Afternoon at Pass Cre... by  Robert E. Wood - Masterpiece Online+by Peter Mohrbacher/The Art of the Craft - by Robert E.
# input_text: Red Boat at Peggy's Cove, Nova Scotia.+make the boat magenta/   output_text: Red Boat at Peggy's Cove, Nova Scotia.+make the boat magenta/blue/green/yellow/purple/white
# input_text: Aisle of the Wawel Cathedral+add rays of sunlight shining down/   output_text: Aisle of the Wawel Cathedral+add rays of sunlight shining down/on the walls of the cathedral+add rays of
# input_text: Kirkjufell by Etienne Ruff on 500px.com+make the background dark/   output_text: Kirkjufell by Etienne Ruff on 500px.com+make the background dark/light/dark/dark/dark/dark/
# input_text: Preparation - Isidor Kaufmann (hungarian painter)+As if it were by Ansel Adams./   output_text: Preparation - Isidor Kaufmann (hungarian painter)+As if it were by Ansel Adams./As if it were by Ansel Adams./As
# input_text: Plums and Roses by Elizabeth Robbins+swap roses with daisies/   output_text: Plums and Roses by Elizabeth Robbins+swap roses with daisies/dandelions+swap flowers with flowers+
# input_text: The Harvesters Print by Henri Lerolle+As a Henri Cartier-Bresson photo./   output_text: The Harvesters Print by Henri Lerolle+As a Henri Cartier-Bresson photo./Photograph by Henri Lerolle+As a
# input_text: Waterfall Scene Painting by numbers+By Robert Frank/   output_text: Waterfall Scene Painting by numbers+By Robert Frank/The Art of Painting by Robert Frank/The Art
# input_text: I've always loved this painting of a woman reading - had no idea the artist was Charles Dickens' son-inlaw - Charles Perugini. #art #literary #Victorian #book+More like a Steve McCurry picture./   output_text: I've always loved this painting of a woman reading - had no idea the artist was Charles Dickens' son-inlaw - Charles Perugini. #art #literary #Victorian #book+More like a Steve McCurry picture./Photographer: David H. H. H.
# input_text: Beargrass and Approaching Storm | Glacier National Park | MT+As if it were by Richard Avedon/   output_text: Beargrass and Approaching Storm | Glacier National Park | MT+As if it were by Richard Avedon/Flickr | CC BY-SA 2.0 |
# input_text: 1 - Twilight on Stephen's Green, Dublin City - Oil Painting - €750+Add a comet in the sky./   output_text: 1 - Twilight on Stephen's Green, Dublin City - Oil Painting - €750+Add a comet in the sky./$750+Add a comet in the sky./
# input_text: 40 How to Wear a Pearl Necklace Ideas 3+Make the necklace a lightning bolt./   output_text: 40 How to Wear a Pearl Necklace Ideas 3+Make the necklace a lightning bolt./Make the necklace a lightning bolt./Make the necklace
# input_text: Leslie Odom Jr. and his wife Nicolette Robinson on the Tonys red carpet.+move them to an urban setting/   output_text: Leslie Odom Jr. and his wife Nicolette Robinson on the Tonys red carpet.+move them to an urban setting/park/parking area.+move them to
# input_text: Brown bear from Tatra Mountains+Add motion blur/   output_text: Brown bear from Tatra Mountains+Add motion blur/lightning to the background of the background of the
# input_text: Art Oil Painting Winter Landscape. The Awakening of Nature. Spring is coming. © shvets_tetiana+Add a picture frame./   output_text: Art Oil Painting Winter Landscape. The Awakening of Nature. Spring is coming. © shvets_tetiana+Add a picture frame./Shvets_tetiana+Add a
# input_text: japanese girl surreal paintings by moki -  9+Add film grain/   output_text: japanese girl surreal paintings by moki -  9+Add film grain/texture/texture/texture/texture/texture/
# input_text: Mount Cook, South Island, New Zealand.+Cover the mountain with cheese./   output_text: Mount Cook, South Island, New Zealand.+Cover the mountain with cheese./Cover the mountain with cheese.+Cover the mountain
# input_text: Badlands National Park+Add an alien abduction/   output_text: Badlands National Park+Add an alien abduction/explosion to the map. This map is not
# input_text: A miniature portrait of French sculptor Auguste Rodin. Courtesy of the Lázaro Galdiano Museum.+Remove his beard./   output_text: A miniature portrait of French sculptor Auguste Rodin. Courtesy of the Lázaro Galdiano Museum.+Remove his beard./Remove his beard.+Remove his beard.+
# input_text: Dorset, watercolour, painting, plein air+Make the lighting more dramatic/   output_text: Dorset, watercolour, painting, plein air+Make the lighting more dramatic/lighten up the atmosphere.
#
# $1
# input_text: Ford by Aaron J Groen+Make it a polaroid./   output_text: Ford by Aaron J Groen+Make it a polaroid./Make it a polaroid.$$$$
# input_text: Oil Painting Reproductions of william-glackens+Replace the humans with zombies/   output_text: Oil Painting Reproductions of william-glackens+Replace the humans with zombies/mummies. The zombies are the same as the
# input_text: Wallpaper Hd Snow Falling Forest Winter Sunrise Germany Snow Trees Cold+More like a tilt shift photo./   output_text: Wallpaper Hd Snow Falling Forest Winter Sunrise Germany Snow Trees Cold+More like a tilt shift photo./Photographer: Michael Schulze, © Michael
# input_text: St Cecilia by Jacques Blanchard - Reproduction Oil Painting+Morph her into a robot/   output_text: St Cecilia by Jacques Blanchard - Reproduction Oil Painting+Morph her into a robot/human form. She is a robot/human form
# input_text: Brent Heighton's  Романтика в Париже+author the work by Mati Klarwein/   output_text: Brent Heighton's  Романтика в Париже+author the work by Mati Klarwein/Brent Heighton's  Ром
# input_text: Fashion Model Red Dress, Woman Dancing in Flying Fabric Gown, Waving Fluttering Cloth 版權商用圖片+have the gown be made of feathers/   output_text: Fashion Model Red Dress, Woman Dancing in Flying Fabric Gown, Waving Fluttering Cloth 版權商用圖片+have the gown be made of feathers/fluttering cloth, and be made of feathers/
# input_text: A beautiful green aurora dancing over the hills, panorama view.+Replace the aurora with a snake/   output_text: A beautiful green aurora dancing over the hills, panorama view.+Replace the aurora with a snake/dragon/dragon/dragon/dragon/dragon/
# input_text: Photograph still life by Anatoly Che on 500px+Change it to a macro lens./   output_text: Photograph still life by Anatoly Che on 500px+Change it to a macro lens./Photograph still life by Anatoly Che on 500
# input_text: "Nat ""King"" Cole"+As a cyanotype/   output_text: "Nat ""King"" Cole"+As a cyanotype/cyanotype of a cyanotype of a cyan
# input_text: Street Light At Night Painting An Artist 39s Life Jane Mcelvany Coonce Oct 2013 The Art+Make it a daguerrotype/   output_text: Street Light At Night Painting An Artist 39s Life Jane Mcelvany Coonce Oct 2013 The Art+Make it a daguerrotype/daguerrotype/daguerro
# input_text: Half Dome Reflected in Merced River, Yosemite Valley, Yosemite National Park, California, USA+Show me the anaglyph instead./   output_text: Half Dome Reflected in Merced River, Yosemite Valley, Yosemite National Park, California, USA+Show me the anaglyph instead./$1.00$1.00$1
# input_text: The Blizzard's Never Seen The Desert Sands  by Thomas Brown+change the blizzard to a tornado/   output_text: The Blizzard's Never Seen The Desert Sands  by Thomas Brown+change the blizzard to a tornado/storm/storm/storm/storm/storm/
# input_text: Traffic on Fifth Avenue along Central Park on rain reflections (large view)+Get rid of the traffic./   output_text: Traffic on Fifth Avenue along Central Park on rain reflections (large view)+Get rid of the traffic./Get rid of the traffic.The street is blocked
# input_text: Spirit Of The Canyon Artwork Original Oil Painting Southwestern Paintings By Steve+Turn it into an 200mm photo/   output_text: Spirit Of The Canyon Artwork Original Oil Painting Southwestern Paintings By Steve+Turn it into an 200mm photo/video camera.$1.00$1.
# input_text: Chile Valley of the Moon Atacama Desert-natural landscape HD wallpaper Views:37189+Make it infrared./   output_text: Chile Valley of the Moon Atacama Desert-natural landscape HD wallpaper Views:37189+Make it infrared./Make it infrared./Make it infrared./Make it
# input_text: Dorothea Lange, 'Migrant Mother', 1936, colorized, via Pixabay/CC0+make the aperature F1.2/   output_text: Dorothea Lange, 'Migrant Mother', 1936, colorized, via Pixabay/CC0+make the aperature F1.2/F2.0/F3.0/
# input_text: Lake Moraine at Sunset+Add an airplane flying low over the lake./   output_text: Lake Moraine at Sunset+Add an airplane flying low over the lake./Add an airplane flying low over the lake./Add
# input_text: Ivar Kamke Drinking men+Taken with a DSLR/   output_text: Ivar Kamke Drinking men+Taken with a DSLR/DLC camera. Ivar Kamke Drinking men
# input_text: Gates of Autumn by Igor Zenin+Let's see this in the winter instead./   output_text: Gates of Autumn by Igor Zenin+Let's see this in the winter instead./The Winter by Igor Zenin+Let's see
# input_text: Venice Canal-Watercolor on Paper+More like a Dr Seuss drawing/   output_text: Venice Canal-Watercolor on Paper+More like a Dr Seuss drawing/drawing/painting/painting/pain
# input_text: "We Officially Have Our First Look At Disney's Live-Action ""Mulan"" And We're Already Excited"+Except the movie is about Calvin & Hobbes instead./   output_text: "We Officially Have Our First Look At Disney's Live-Action ""Mulan"" And We're Already Excited"+Except the movie is about Calvin & Hobbes instead./"We're Already Excited"+Except the
# input_text: Sir Gerald Festus Kelly, Portrait of a Seated Lady at Morgan O'Driscoll Art Auctions+Make it a flash photograph/   output_text: Sir Gerald Festus Kelly, Portrait of a Seated Lady at Morgan O'Driscoll Art Auctions+Make it a flash photograph/photograph of a seated lady at Morgan O'
# input_text: """Autry National Center +make it floating on clouds./   output_text: """Autry National Center +make it floating on clouds./Make it float on clouds./Make it float on
# input_text: Jasper National Park, Canada, Alberta, Athabasca, River, Valley, Winter, panorama, mountains, snow, winter, sunrise+In Yellowstone instead/   output_text: Jasper National Park, Canada, Alberta, Athabasca, River, Valley, Winter, panorama, mountains, snow, winter, sunrise+In Yellowstone instead/with the same name as the park, the park
# input_text: Klinkenberg view of the Singel in winter - J.C.K. Klinkenberg (1852-1924),+Make the colors warmer./   output_text: Klinkenberg view of the Singel in winter - J.C.K. Klinkenberg (1852-1924),+Make the colors warmer./Make the colors warmer.Klinkenberg view of
# input_text: Picture summer, clouds, mountains, lake, the evening, morning, Bled, Bled lake, Church Of The Assumption Of ...+What if the image were captured at golden hour instead?/   output_text: Picture summer, clouds, mountains, lake, the evening, morning, Bled, Bled lake, Church Of The Assumption Of...+What if the image were captured at golden hour instead?/What if the image were captured at golden hour instead
# input_text: Samurai by TVviST+Make it a photo lit by police car lights./   output_text: Samurai by TVviST+Make it a photo lit by police car lights./Make it a photo lit by police car lights./
# input_text: Lost In the Winter Woods+Make the lighting more cinematic/   output_text: Lost In the Winter Woods+Make the lighting more cinematic/realistic. Make the lighting more realistic/real
# input_text: The Outer Worlds Header Image+make it a lush vibrant green/   output_text: The Outer Worlds Header Image+make it a lush vibrant green/purple/yellow/green/blue/pur
# input_text: Christopher Rimmer's Haunting Images of Abandoned Towns Buried by Sand.+Add purple and yellow lights./   output_text: Christopher Rimmer's Haunting Images of Abandoned Towns Buried by Sand.+Add purple and yellow lights./Add red and green lights./Add blue and green
# input_text: 1600x1000 - Mountaineering Wallpapers 28+Lit by fireworks./   output_text: 1600x1000 - Mountaineering Wallpapers 28+Lit by fireworks./Mountaineering Wallpapers 28+Lit by
# input_text: Young lady in traditional clothes, Bangladesh by David Lazar+change to traditional Guatemalan clothing/   output_text: Young lady in traditional clothes, Bangladesh by David Lazar+change to traditional Guatemalan clothing/socks, and a few other things.The
# input_text: divine comedy chapters+as a sticker collection/   output_text: divine comedy chapters+as a sticker collection/book+as a sticker collection/book+as
# input_text: Illustration of Shareworks United Kingdom employees hanging out in a trendy office lounge.+as a backlit photo./   output_text: Illustration of Shareworks United Kingdom employees hanging out in a trendy office lounge.+as a backlit photo./as a backlit photo.$1.00
# input_text: Vineyard At Dentelles Original by Diane McClary+Make it overcast/   output_text: Vineyard At Dentelles Original by Diane McClary+Make it overcast/darkened/darkened/darkened/dark
# input_text: Artodyssey lee bogle for Crazy mural lady+make the lady have glowing eyes/   output_text: Artodyssey lee bogle for Crazy mural lady+make the lady have glowing eyes/eyes+make the lady have glowing eyes/eyes
# input_text: Girls_ice_hockey_team_1921+change to a soccer team./   output_text: Girls_ice_hockey_team_1921+change to a soccer team./$1$1$1$1$1
# input_text: Beautiful medium sized painting, stretched but without frame, by Raspail.  The Eiffel Tower sits at the end of a Paris street filled with people and carriages.+Add some colorful lights/   output_text: Beautiful medium sized painting, stretched but without frame, by Raspail.  The Eiffel Tower sits at the end of a Paris street filled with people and carriages.+Add some colorful lights/glasses to the painting.+Add some more
# input_text: Asami Sato - The Legend of Korra by eerilyfair+But the story is about Ben Stiller./   output_text: Asami Sato - The Legend of Korra by eerilyfair+But the story is about Ben Stiller./The Legend of Korra by eerilyfair+
# input_text: 71 Japanese Animation Wallpapers on WallpaperPlay 1920x1080+make the wallpaper Scandinavian/   output_text: 71 Japanese Animation Wallpapers on WallpaperPlay 1920x1080+make the wallpaper Scandinavian/English/French/German/Italian/Japanese/
# input_text: Art Exhibition - Yorkshire Landscapes: Image 0+add bigfoot/   output_text: Art Exhibition - Yorkshire Landscapes: Image 0+add bigfoot/bigfoot/bigfoot/bigfoot/big
# input_text: Ali Fazal in Victoria and Abdul+Let's add Vin Diesel to the movie/   output_text: Ali Fazal in Victoria and Abdul+Let's add Vin Diesel to the movie/TV series. He's a very good actor.
# input_text: robert finale le paris cafe+More vaporwave/   output_text: robert finale le paris cafe+More vaporwave/vaporwave/vaporwave/vapor
# input_text: Joyous Memories Sold Out lady painter Pino Daeni Oil Paintings+Make it more melancholic and dark./   output_text: Joyous Memories Sold Out lady painter Pino Daeni Oil Paintings+Make it more melancholic and dark./Make it more melancholic and dark./Make it
# input_text: Kirkjufellsfoss in the evening by Robert Didierjean on 500px.com+combine with grass hills/   output_text: Kirkjufellsfoss in the evening by Robert Didierjean on 500px.com+combine with grass hills/creek hills/creek hills/creek
# input_text: Wallpaper Figure Castle Silhouette Warrior Landscape Fortress 1332x850+More steampunk./   output_text: Wallpaper Figure Castle Silhouette Warrior Landscape Fortress 1332x850+More steampunk./More steampunk./More steampunk./More ste
# input_text: Autumn in the Blue Mountains by SteveCampbell+Make it more vibrant, pink, and spirited./   output_text: Autumn in the Blue Mountains by SteveCampbell+Make it more vibrant, pink, and spirited./Make it more vibrant, pink, and spirited.
# input_text: Acrylic Paints Painting - Bb King Portrait by Richard Day+Memphis group, corporate, 1980s./   output_text: Acrylic Paints Painting - Bb King Portrait by Richard Day+Memphis group, corporate, 1980s./Photograph by Richard Day+Memphis group,
# input_text: Michael Nelson HISTORICAL WOMAN IN BODICE REFLECTED IN MIRROR Women+she is an angel/   output_text: Michael Nelson HISTORICAL WOMAN IN BODICE REFLECTED IN MIRROR Women+she is an angel/woman who is a woman who is a woman who
# input_text: ELLA FITZGERALD (1917-1996) American singer. Performing on stage with Dizzy Gillespie. Photograph by William P. Gottlieb, c.1947.+Add Nicolas Cage to the mix./   output_text: ELLA FITZGERALD (1917-1996) American singer. Performing on stage with Dizzy Gillespie. Photograph by William P. Gottlieb, c.1947.+Add Nicolas Cage to the mix./Add Nicolas Cage to the mix.$1.
# input_text: animal-children-photography-elena-shumilova-33+make them elephant children/   output_text: animal-children-photography-elena-shumilova-33+make them elephant children/photography-elena-shumilova
# input_text: Wallpapers 2560x1440 Cars Wallpaper Moraine Lake Banff Canada Mountains Forest+turn into F1 racing cars./   output_text: Wallpapers 2560x1440 Cars Wallpaper Moraine Lake Banff Canada Mountains Forest+turn into F1 racing cars./draws/draws/draws/draw
# input_text: 310-julie-thomas-robbers-bridge-what-a-beautiful-place-for-our-walk-and-picnic-today+Remove the bridge/   output_text: 310-julie-thomas-robbers-bridge-what-a-beautiful-place-for-our-walk-and-picnic-today+Remove the bridge/cabinet/cabinet/cabin
# input_text: Lonely boat and amazing sunset at the sea+Less sunset/   output_text: Lonely boat and amazing sunset at the sea+Less sunset/sunrise at the sea+Less sunset/sun
# input_text: Photograph Monocurve by Ted Gore on 500px+Show this from above./   output_text: Photograph Monocurve by Ted Gore on 500px+Show this from above./Photograph Monocurve by Ted Gore on
# input_text: Stunning Paintings of Bodies Floating on the Surface of The Water – Fubiz Media Design+Morph the people into turnips/   output_text: Stunning Paintings of Bodies Floating on the Surface of The Water – Fubiz Media Design+Morph the people into turnips/paintings of bodies floating on the surface of
# input_text: Nasir-ul Molk Mosque with all of the the Rainbow Colors+Make it look like the Palace of Versailles./   output_text: Nasir-ul Molk Mosque with all of the the Rainbow Colors+Make it look like the Palace of Versailles./Make it look like the Palace of Versailles
# input_text: Bridal Veil Fall, Yosemite Valley By Thomas Hill By Thomas Hill Art Reproduction+Remove the waterfall/   output_text: Bridal Veil Fall, Yosemite Valley By Thomas Hill By Thomas Hill Art Reproduction+Remove the waterfall/garden/garden/garden/g
# input_text: Robin Moline - Snow Covered Village+Remove the snow./   output_text: Robin Moline - Snow Covered Village+Remove the snow./Remove the snow.$1.00$1
# input_text: Small Boy On A Donkey Near A Palm Plantation+Put the boy on the ground/   output_text: Small Boy On A Donkey Near A Palm Plantation+Put the boy on the ground/on the ground/on the ground/on the
# input_text: painting-of-forest-and-pond+Without the water./   output_text: painting-of-forest-and-pond+Without the water./The water is a beautiful thing. It's a
# input_text: Soldier girl with a sniper rifle - Obrázkek zdarma+Have her hold a bundle of flowers instead/   output_text: Soldier girl with a sniper rifle - Obrázkek zdarma+Have her hold a bundle of flowers instead/have her hold a bundle of flowers instead/have
# input_text: watercolour painting, Ullswater, Cumbria+as a photograph taken with Sigma 50mm lens/   output_text: watercolour painting, Ullswater, Cumbria+as a photograph taken with Sigma 50mm lens/Nikon D750/D750/D750
# input_text: Tourrettes_patio_HDR_D3S3904a+with soft focus/   output_text: Tourrettes_patio_HDR_D3S3904a+with soft focus/lightning/lightning/lightning/light
# input_text: Cool businessman sits on a brick wall with newspaper Archivio Fotografico+Take away his newspaper./   output_text: Cool businessman sits on a brick wall with newspaper Archivio Fotografico+Take away his newspaper./Take away his newspaper. Take away his newspaper.
# input_text: portrait of artist albert beck wenzell (1864-1917) by william merritt chase+make it a portrait ot Lebron James/   output_text: portrait of artist albert beck wenzell (1864-1917) by william merritt chase+make it a portrait ot Lebron James/The New York Times/Library of Congress/Library
# input_text: Lavender Field Painting - Impressionist Art Print by Lourry Legarde+Swap the lavender for sunflowers./   output_text: Lavender Field Painting - Impressionist Art Print by Lourry Legarde+Swap the lavender for sunflowers./Lourry Legarde+Swap the lav
# input_text: Dogs Painting - Evening Walk by Merle Keller+Turn dogs into mini dinosaurs/   output_text: Dogs Painting - Evening Walk by Merle Keller+Turn dogs into mini dinosaurs/mammals. You can also use the painting
# input_text: A motif from Rothenburg upon Tauber river.+have the river be made of grape juice/   output_text: A motif from Rothenburg upon Tauber river.+have the river be made of grape juice/water.+have the river be made of water
# input_text: 18x20in, Charcoal on Paper, Sept.2018+Make this a 3D render/   output_text: 18x20in, Charcoal on Paper, Sept.2018+Make this a 3D render/texture for your own use.$1.00
# input_text: O mundo é bão, Sebastião Game Review - Bastion+as a grainy black-and-white film/   output_text: O mundo é bão, Sebastião Game Review - Bastion+as a grainy black-and-white film/artwork by Sebastião Game Review - Bast
# input_text: Adrienne Ames (Aug 3 1907 – May 31 an American film actress. Born Adrienne Ruth McClure in Fort Worth, Texas Hollywood Stars, Old Hollywood Glamour, Golden Age Of Hollywood, Vintage Glamour, Vintage Beauty, Classic Hollywood, Classic Movie Stars, Classic Films, Divas+Make her an Indian Bollywood star/   output_text: Adrienne Ames (Aug 3 1907 – May 31 an American film actress. Born Adrienne Ruth McClure in Fort Worth, Texas Hollywood Stars, Old Hollywood Glamour, Golden Age Of Hollywood, Vintage Glamour, Vintage Beauty, Classic Hollywood, Classic Movie Stars, Classic Films, Divas+Make her an Indian Bollywood star/model. Adrienne Ames (Aug 3 1907
# input_text: Mount Washington by William F. Paskell+add an ocean to the foreground/   output_text: Mount Washington by William F. Paskell+add an ocean to the foreground/background of the painting.The painting is a very
# input_text: Painting - On The Old Blanco Road, Southwest Texas by Julian Onderdonk+Add wild horses./   output_text: Painting - On The Old Blanco Road, Southwest Texas by Julian Onderdonk+Add wild horses./The Old Blanco Road, Southwest Texas by Julian
# input_text: portrait of a young lady+Make it a professional headshot/   output_text: portrait of a young lady+Make it a professional headshot/make it a professional headshot/make it a
# input_text: Birds include bamboo, Japanese painting wallpapers and images wallpapers, pictures, photos+turn birds to bees/   output_text: Birds include bamboo, Japanese painting wallpapers and images wallpapers, pictures, photos+turn birds to bees/flies, birds, birds, birds, birds,
# input_text: Riches worth £26million belonging to the family of Russia's last tsar, Nicholas II, are believed to be hidden close to the Trans-Siberian railway track about 2,215 miles east of Moscow+Highlight the riches in yellow/   output_text: Riches worth £26million belonging to the family of Russia's last tsar, Nicholas II, are believed to be hidden close to the Trans-Siberian railway track about 2,215 miles east of Moscow+Highlight the riches in yellow/blue/green/yellow/green/yellow/
# input_text: sunrise mountains mountain lake reflection water clouds skies sky trees pinetrees idaho canon5diii outdoor landscapes landscape tree forest wood+Change it to midday lighting./   output_text: sunrise mountains mountain lake reflection water clouds skies sky trees pinetrees idaho canon5diii outdoor landscapes landscape tree forest wood+Change it to midday lighting./Change it to sunset lighting./Change it to sunrise
# input_text: 2014-SEP-Guild-Docks-Of-Valura-by-FrankAtt.jpg+Taken in January 1995/   output_text: 2014-SEP-Guild-Docks-Of-Valura-by-FrankAtt.jpg+Taken in January 1995/1996.jpg+Taken in January 1995/
# input_text: Vivian Maier, Untitled, 1954+as a linoleum print/   output_text: Vivian Maier, Untitled, 1954+as a linoleum print/paper, with a few other prints, including a
# input_text: Lone Tree Hill, Eddie Doherty, Drogheda Photographic Club+Add dramatic backlighting/   output_text: Lone Tree Hill, Eddie Doherty, Drogheda Photographic Club+Add dramatic backlighting/backgrounds to the landscape. The landscape is a
# input_text: Reflection of hiker beneath Piz Bernina and Piz Rosbeg, Fuorcla Surlej, Berniner Alps, Graubunden, Switzerland.+increase to a group of hikers/   output_text: Reflection of hiker beneath Piz Bernina and Piz Rosbeg, Fuorcla Surlej, Berniner Alps, Graubunden, Switzerland.+increase to a group of hikers/hikers in the area of Piz Bernina
# input_text: emmys-red-carpet-best-dressed-emma-roberts+Actually Keanu Reeves would be better/   output_text: emmys-red-carpet-best-dressed-emma-roberts+Actually Keanu Reeves would be better/more attractive than Keanu Reeves. He's a
# input_text: Beautiful Places On Earth Iceland Beautiful Landscape Wallpaper+Insert a giant blue teddy bear./   output_text: Beautiful Places On Earth Iceland Beautiful Landscape Wallpaper+Insert a giant blue teddy bear./Insert a giant blue teddy bear./Insert a
# input_text: Big Horn Sheeps+Horns are too big/   output_text: Big Horn Sheeps+Horns are too big/too small to be seen in the sky. They
# input_text: A Heartbeat at Lake Ediza and the Milky Way+Replace the Milky Way with the Pleiades./   output_text: A Heartbeat at Lake Ediza and the Milky Way+Replace the Milky Way with the Pleiades./A Heartbeat at Lake Ediza and the Milky
# input_text: Steve hanks Quiet rapport+at an oasis/   output_text: Steve hanks Quiet rapport+at an oasis/downtown/downtown/downtown/d
# input_text: Dear Hedy what about you thinking? Golden Age Of Hollywood, Vintage Hollywood, Hollywood Glamour, Classic Hollywood, Hedy Lamarr, Gina Lollobrigida, She's A Lady, Old Actress, Classic Beauty+turn young and modern/   output_text: Dear Hedy what about you thinking? Golden Age Of Hollywood, Vintage Hollywood, Hollywood Glamour, Classic Hollywood, Hedy Lamarr, Gina Lollobrigida, She's A Lady, Old Actress, Classic Beauty+turn young and modern/modern, and you're not going to be able
# input_text: 48 Indoor Swimming Pool Ideas Taking A Dip In Style Unique Backyard Pool Designs Exterior+More gothic/   output_text: 48 Indoor Swimming Pool Ideas Taking A Dip In Style Unique Backyard Pool Designs Exterior+More gothic/gothic/gothic/goth
# input_text: © Oleg Oprisco - Soul Images | Fotografía | Photography+More bleak and stormy./   output_text: © Oleg Oprisco - Soul Images | Fotografía | Photography+More bleak and stormy./Fotografía | Photography+More bleak
# input_text: Paternkofel (Left) and Tre Cime Di Lavaredo Mountains at Sunset, Sexten Dolomites, Tyrol, Italy+turn Paternkofel into Zhangjiajie Pillars/   output_text: Paternkofel (Left) and Tre Cime Di Lavaredo Mountains at Sunset, Sexten Dolomites, Tyrol, Italy+turn Paternkofel into Zhangjiajie Pillars/Paternkofel into Tre Cime Di
# input_text: Summer Night on the South Beach at Skagen by Peder Severin Krøyer on Curiator – http://crtr.co/1oiy+set it on fire./   output_text: Summer Night on the South Beach at Skagen by Peder Severin Krøyer on Curiator – http://crtr.co/1oiy+set it on fire./$1.99$1.99$1
# input_text: Charlize Therone in Dior. (Photo: ABC/Rick Rowell)+Let's see an extreme close up/   output_text: Charlize Therone in Dior. (Photo: ABC/Rick Rowell)+Let's see an extreme close up/close up of the face of the woman in the
# input_text: hyper realistic flower painting+turn flower into a pinecone/   output_text: hyper realistic flower painting+turn flower into a pinecone/pink flower+turn flower into a pinecone
# input_text: Alpenglow strikes El Capitan, Yosemite.+grow moss on the side/   output_text: Alpenglow strikes El Capitan, Yosemite.+grow moss on the side/top of the cliff+grow moss on the side
# input_text: Fishing on a Quiet Backwater by Henry John Yeend King - 24 x 36 inches Signed british victorian genre figures figurative gardens peasants realist+infest the water with sharks./   output_text: Fishing on a Quiet Backwater by Henry John Yeend King - 24 x 36 inches Signed british victorian genre figures figurative gardens peasants realist+infest the water with sharks./The Water of the Sea by Henry John Yeend
# input_text: Figurative watercolor of a young woman draped in green fabric+As a marble statue/   output_text: Figurative watercolor of a young woman draped in green fabric+As a marble statue/skeleton of a young woman draped in green fabric
# input_text: Two by Pedro Ribeiro - Landscapes Waterscapes+Give it more of a brass or metal vibe./   output_text: Two by Pedro Ribeiro - Landscapes Waterscapes+Give it more of a brass or metal vibe./The first time I saw this I was so excited
# input_text: Original oil painting of fishing boat and sea on canvas. Sunset over ocean and coastal town.Modern Impressionism+In the style of 1990s Disney/   output_text: Original oil painting of fishing boat and sea on canvas. Sunset over ocean and coastal town.Modern Impressionism+In the style of 1990s Disney/Disney/Marvel/Marvel/Marvel/Marvel/
# input_text: Elliptical City by 2buiArt+make it square/   output_text: Elliptical City by 2buiArt+make it square/square/square/square/square/square/
# input_text: Murmur of the Innocents 13 (detail) by gottfriedhelnwein+Needs to be more joyous and cheerful/   output_text: Murmur of the Innocents 13 (detail) by gottfriedhelnwein+Needs to be more joyous and cheerful/happy/happy/happy/happy/happy/
# input_text: One of the most photographed locations in Canada, Moraine lake , is arguably one of the  world's most beautiful glacier-fed...+make it ugly/   output_text: One of the most photographed locations in Canada, Moraine lake, is arguably one of the  world's most beautiful glacier-fed...+make it ugly/beautiful+make it look like a glacier+
# input_text: Chief Red Cloud Poster+raise an eyebrow/   output_text: Chief Red Cloud Poster+raise an eyebrow/hair/hair/hair/hair/hair/
# input_text: """Ghost Ranch - New Mexico 11"""" x 14"""" oil painting by Tom Haas"""+More like an office building./   output_text: """Ghost Ranch - New Mexico 11"""" x 14"""" oil painting by Tom Haas"""+More like an office building./$1.00$1.00$1
# input_text: Lewis Wickes Hine, �Man on Girders, Mooring Mast, Empire State Building,� c. 1931+Make it by Alexander Jansson/   output_text: Lewis Wickes Hine, �Man on Girders, Mooring Mast, Empire State Building,� c. 1931+Make it by Alexander Jansson/The New York Times, New York, New York
# input_text: 45 Scenic Self-Portraits That Will Take You Places+Andrew Wyeth's version./   output_text: 45 Scenic Self-Portraits That Will Take You Places+Andrew Wyeth's version./Photograph by Andrew Wyeth.
# input_text: Buachaille Etive Mor by .Brian Kerr Photography.+By Giacomo Balla/   output_text: Buachaille Etive Mor by.Brian Kerr Photography.+By Giacomo Balla/Photography.+By Giacomo Balla
# input_text: Tableaux Aquarelle Paysages Par Winter Painting Winter+But as if Agnes Lawrence Pelton painted it./   output_text: Tableaux Aquarelle Paysages Par Winter Painting Winter+But as if Agnes Lawrence Pelton painted it./$1.00$1.00$1
# input_text: Dining Room Wall Murals by Tuscan Landscapes Www Ericdbeare Com+make the mural a window instead./   output_text: Dining Room Wall Murals by Tuscan Landscapes Www Ericdbeare Com+make the mural a window instead./$1$1$1$1$1
# input_text: Wallpaper Archer, deer, people, the moon, winter, ice, North, cold+In the style of Christophe Vacher./   output_text: Wallpaper Archer, deer, people, the moon, winter, ice, North, cold+In the style of Christophe Vacher./The painting of the moon, the moon, the
# input_text: Rosamund Pike in Vera Wang - 2015 Golden Globes+Put her in front of a green screen./   output_text: Rosamund Pike in Vera Wang - 2015 Golden Globes+Put her in front of a green screen./Photograph by: Michael S. Williamson/Getty
# input_text: <p>Considered a great beauty in her youth, with a tall, graceful figure, the Grand Duchess Alexandra, or &lsquo;Sanny&rsquo;, was the fifth daughter of Joseph, Duke of Saxe-Altenburg and Amalie Therese Louise, Duchess of W&uuml;rttemberg. In September 184+Make the foreground blurry/   output_text: <p>Considered a great beauty in her youth, with a tall, graceful figure, the Grand Duchess Alexandra, or &lsquo;Sanny&rsquo;, was the fifth daughter of Joseph, Duke of Saxe-Altenburg and Amalie Therese Louise, Duchess of W&uuml;rttemberg. In September 184+Make the foreground blurry/darker, and the background darker. The background
# input_text: Amazing View in autumn  : Bled Lake, Island,Church And Castle With Mountain Range (Stol, Vrtaca, Begunjscica) In The Background-Bled,Slovenia,Europe+As tilt shift photo/   output_text: Amazing View in autumn  : Bled Lake, Island,Church And Castle With Mountain Range (Stol, Vrtaca, Begunjscica) In The Background-Bled,Slovenia,Europe+As tilt shift photo/video: http://www.youtube.com/
# input_text: Enchanting Paintings Capture the Twinkling Beauty of Paris at Twilight+Add lots of bokeh/   output_text: Enchanting Paintings Capture the Twinkling Beauty of Paris at Twilight+Add lots of bokeh/glitter to your painting. You can also add
# input_text: Seascapes, landscapes, figurative, seasonal -- Steve Henderson Fine Art creates all types of fine art+Make it a macro lens photo/   output_text: Seascapes, landscapes, figurative, seasonal -- Steve Henderson Fine Art creates all types of fine art+Make it a macro lens photo/photograph+Make it a digital lens photo/
# input_text: amazing-photography-beautiful-fairy-tale-photos (6)+Shot on a Kodak Portra 400/   output_text: amazing-photography-beautiful-fairy-tale-photos (6)+Shot on a Kodak Portra 400/400/400/400/400/400/
# input_text: Girl with a pearl earring and an Octopus+swap with Oprah Winfrey/   output_text: Girl with a pearl earring and an Octopus+swap with Oprah Winfrey/Sharon Brando$$$$$$
# input_text: 'White Dress' Back, Figurative Art, Figurativism, Artwork, Paintings, Sculptures, Representational Art, Figure Painting,  Human Figure, Modern Art, Figurative Artists, Real objects,+turn the dress orange/   output_text: 'White Dress' Back, Figurative Art, Figurativism, Artwork, Paintings, Sculptures, Representational Art, Figure Painting,  Human Figure, Modern Art, Figurative Artists, Real objects,+turn the dress orange/yellow/blue/green/yellow/blue/
# input_text: Stan Miller Watercolor - Google Search+Captured by a Canon 1D X/   output_text: Stan Miller Watercolor - Google Search+Captured by a Canon 1D X/Y Camera - Google Search+Captured by a
# input_text: An Introduction To Futurist Art In 12 Works+change to antique art/   output_text: An Introduction To Futurist Art In 12 Works+change to antique art/art, and to the art of the artist,
# input_text: Pink Skunk Anemone Fish, Amphiprion perideraion, Fiji, Amphiprion perideraion+make it a Emperor Angelfish/   output_text: Pink Skunk Anemone Fish, Amphiprion perideraion, Fiji, Amphiprion perideraion+make it a Emperor Angelfish/Fairy Fish, Amphiprion perider
# ...
# input_text: Candice Swanepoel is gorgeous in a plunging lace gown at the 2015 Met Gala+make her look empowered/   output_text: Candice Swanepoel is gorgeous in a plunging lace gown at the 2015 Met Gala+make her look empowered/beautiful in a plunging lace gown at the
# input_text: Resonance Of Fate (End Of Eternity - 79.6KB+the sky is darkening/   output_text: Resonance Of Fate (End Of Eternity - 79.6KB+the sky is darkening/darkening/darkening/darkening/dark
# input_text: AB notre dame quai saint michel 2 Paris Oil Paintings+turn it into a painting of the Magritte Museum/   output_text: AB notre dame quai saint michel 2 Paris Oil Paintings+turn it into a painting of the Magritte Museum/The Magritte Museum/The Magritte
# input_text: Edward Hopper-Room in New York+make it a hotel room/   output_text: Edward Hopper-Room in New York+make it a hotel room/house of horrors+make it a haunted house+
# input_text: Bertrand Gentou and Olivier Vandenbergh on the beautiful snow arete of the Innominata Ridge, Mont Blanc+Make the arete thinner./   output_text: Bertrand Gentou and Olivier Vandenbergh on the beautiful snow arete of the Innominata Ridge, Mont Blanc+Make the arete thinner./Make the arete thicker.$$Make the
# input_text: Golden luxury Jewelry. Manicured nail. Fashion art photo of young woman isolated on beige background. Zdjęcie Seryjne+change the background color/   output_text: Golden luxury Jewelry. Manicured nail. Fashion art photo of young woman isolated on beige background. Zdjęcie Seryjne+change the background color/color of the nail to match the color of the
# input_text: oil painting of Gore Creek, Co., by John Hulsey+have it be a different medium/   output_text: oil painting of Gore Creek, Co., by John Hulsey+have it be a different medium/color. I'm not sure if it's a
# input_text: Full HD 1080p Italy Wallpapers HD, Desktop Backgrounds ...+make the sky orange/   output_text: Full HD 1080p Italy Wallpapers HD, Desktop Backgrounds...+make the sky orange/green/blue/yellow/purple/pur
# input_text: Steve Hanks Beyond The Horizon+Use a 35mm film stock/   output_text: Steve Hanks Beyond The Horizon+Use a 35mm film stock/film stock to create a 3D effect. This
# input_text: black and white vogue style portrait of delicate blonde woman+make the woman look like a clown/   output_text: black and white vogue style portrait of delicate blonde woman+make the woman look like a clown/soul+make the woman look like a clown
# input_text: Cypress reflections in Caddo Lake.+make it a daydream/   output_text: Cypress reflections in Caddo Lake.+make it a daydream/dreamscape+make it a daydream/dream
# input_text: Traditional Fisherman on Inle Lake at sunrise, Shan State Myanmar/Burma+As a headshot./   output_text: Traditional Fisherman on Inle Lake at sunrise, Shan State Myanmar/Burma+As a headshot./Photographer: R.A.M.
#
# input_text: Vasco da Gama Bridge is a great photography location for our Lisbon photography guide+Add a helicopter/   output_text: Vasco da Gama Bridge is a great photography location for our Lisbon photography guide+Add a helicopter/plane to your tour. The bridge is located in
# input_text: Yosemite's Rainbow.  Yosemite National Park, California.+make it after a storm/   output_text: Yosemite's Rainbow.  Yosemite National Park, California.+make it after a storm/storm.+make it after a storm/storm
# input_text: Venice. by Olga Shiropaeva (Olga_Shiropaeva)) on 500px.com+Change the city to Florence./   output_text: Venice. by Olga Shiropaeva (Olga_Shiropaeva)) on 500px.com+Change the city to Florence./Change the city to Florence.$Change the city
# input_text: Louis Aston Knight - Peisaje exceptionale+Image is by David Hockney/   output_text: Louis Aston Knight - Peisaje exceptionale+Image is by David Hockney/The Guardian.
#
# The Peisaje
# input_text: the-lonely-mountain+place the lonely mountain in the woods/   output_text: the-lonely-mountain+place the lonely mountain in the woods/forest of the woods/forest of the woods/
# input_text: 2017 Kauai Photo Workshop :: Kalalau Valley Sunset+Add a light drizzle/   output_text: 2017 Kauai Photo Workshop :: Kalalau Valley Sunset+Add a light drizzle/light rain to the sky. This is a beautiful
# input_text: Sunbeams, Ouray, Colorado, photo+make the sunbeams a solar flare/   output_text: Sunbeams, Ouray, Colorado, photo+make the sunbeams a solar flare/sunshine, and a solar flare/sunshine
# input_text: mike moh+make him a teacher/   output_text: mike moh+make him a teacher/student$$$$$$$$$
# input_text: Coniston Water Canvas print by Graham Moore+use a sepia filter/   output_text: Coniston Water Canvas print by Graham Moore+use a sepia filter/brush to create a beautiful, vibrant, and vibrant
# input_text: Safari stylized blender3d landscape 3d animation illustration+turn into a scene from minecraft/   output_text: Safari stylized blender3d landscape 3d animation illustration+turn into a scene from minecraft/minecraft/blockcraft/blockcraft/blockcraft
# input_text: A woman in a dress dress walks through the foggy forest.+Have her be barefoot./   output_text: A woman in a dress dress walks through the foggy forest.+Have her be barefoot./Have her be barefoot./Have her be bare
# input_text: Snowy Day, Central Park, New York City .... Ok, this is most likely why I'm not in NYC ... Still so pretty+change the time to evening/   output_text: Snowy Day, Central Park, New York City.... Ok, this is most likely why I'm not in NYC... Still so pretty+change the time to evening/morning/evening. I'm not sure if
# input_text: Deep-forest-and-fog-in-Holland-photo-by-Ellen-Borggreve+turn the fog into dark smoke/   output_text: Deep-forest-and-fog-in-Holland-photo-by-Ellen-Borggreve+turn the fog into dark smoke/dark clouds/dark clouds/dark clouds/dark
# input_text: The reader (FINEART)+read a newspaper/   output_text: The reader (FINEART)+read a newspaper/magazine/magazine/magazine/mag
# input_text: Mark Keathley's Midnight Clear+Change the time of day/   output_text: Mark Keathley's Midnight Clear+Change the time of day/night to midnight. This is the time of day
# input_text: Classic painterly dark renaissance portrait of a girl in black dress with a long braid hanging across her shoulder+make it a school portrait/   output_text: Classic painterly dark renaissance portrait of a girl in black dress with a long braid hanging across her shoulder+make it a school portrait/paint it a school portrait/paint it
# input_text: The Lillies by Natalia Beccher+have them grow on a vine/   output_text: The Lillies by Natalia Beccher+have them grow on a vine/tree. They are very hard to find. They
# input_text: Jan Lisiecki ©Christoph Köstlin+By Dan Leydet/   output_text: Jan Lisiecki ©Christoph Köstlin+By Dan Leydet/Photographer©Christoph Köstlin+
# input_text: Scenic Landscape Illustrations with Vibrant Colors+Change the color palette/   output_text: Scenic Landscape Illustrations with Vibrant Colors+Change the color palette/color palette/color palette/color palette/color
# input_text: The famous Palouse rolling hills+change it to the hills of Utah/   output_text: The famous Palouse rolling hills+change it to the hills of Utah/Utah/Utah/Utah/Utah/Utah/
# input_text: Empress of china makeup_1+as a pagan goddess/   output_text: Empress of china makeup_1+as a pagan goddess/soul_of_the_sun_of
# input_text: Bob Ross : Bubbling Mountain Brook+make the mountain more jagged/   output_text: Bob Ross : Bubbling Mountain Brook+make the mountain more jagged/deeper.$$$$$$$
# input_text: France - Vienne - St Maurice Cathedral.jpg+add a cactus garden/   output_text: France - Vienne - St Maurice Cathedral.jpg+add a cactus garden/cactus garden/cactus garden/cactus
# input_text: Painting - Carmel Mission Garden, Plein Air by Marie Massey+transform into a meadow/   output_text: Painting - Carmel Mission Garden, Plein Air by Marie Massey+transform into a meadow/forest/forest/forest/forest/forest/
# input_text: Stained glass of Sainte-Chapelle+Make the stained glass more abstract./   output_text: Stained glass of Sainte-Chapelle+Make the stained glass more abstract./Make the stained glass more abstract./Make the stained
# input_text: A la fontaine | Jules Breton | Oil Painting+as a photograph/   output_text: A la fontaine | Jules Breton | Oil Painting+as a photograph/photograph of a painting, or a photograph of
# input_text: Waterfall on River Coupall Overlooking Buchaille Etive Mor+make the water raging/   output_text: Waterfall on River Coupall Overlooking Buchaille Etive Mor+make the water raging/waterfall on the river Coupall Overlooking Buch
# input_text: by Richard  Harris - Landscapes Mountains & Hills+Turn the hills in to mountains/   output_text: by Richard  Harris - Landscapes Mountains & Hills+Turn the hills in to mountains/hills. This is a great way to get
# input_text: Andalusian Farmhouse+make it an ancient Mayan farmhouse/   output_text: Andalusian Farmhouse+make it an ancient Mayan farmhouse/house of the gods+make it an ancient May
# input_text: 10 Latest Dark Fantasy Hd Wallpapers FULL HD 1080p For PC Background 2021 free download nice free fantasy wallpapers for desktop 40 diariovea 1024x660+Instead of Dark Fantasy, make it Romanticism./   output_text: 10 Latest Dark Fantasy Hd Wallpapers FULL HD 1080p For PC Background 2021 free download nice free fantasy wallpapers for desktop 40 diariovea 1024x660+Instead of Dark Fantasy, make it Romanticism./Dark Fantasy Hd Wallpapers for PC Background 2021
# input_text: Gothic Forest 1980 Limited Edition Print - Eyvind Earle+turn it into a Game Boy Color game/   output_text: Gothic Forest 1980 Limited Edition Print - Eyvind Earle+turn it into a Game Boy Color game/game/game/game/game/game/
# input_text: Download-Assassins-Creed-Syndicate-Evie-Frye-1920x1080-wallpaper-wp3404785+make Evie a cat/   output_text: Download-Assassins-Creed-Syndicate-Evie-Frye-1920x1080-wallpaper-wp3404785+make Evie a cat/dog/cat/dog/dog/dog/
# input_text: Tomorrowland-Syd-Mead-Concept-Art (1)+make it nighttime/   output_text: Tomorrowland-Syd-Mead-Concept-Art (1)+make it nighttime/daylight/nightmare/daylight/day
# input_text: First Snow Surrey Hills (acrylic ink)_+Make it a sunset./   output_text: First Snow Surrey Hills (acrylic ink)_+Make it a sunset./Make it a sunset.$1.00$
# input_text: Frozen Sunrise over Mount Rundle+Replace Mount Rundle with Mount Kilimanjaro/   output_text: Frozen Sunrise over Mount Rundle+Replace Mount Rundle with Mount Kilimanjaro/Mount Rundle+Replace Mount Rundle with
# input_text: The Alhambra From Calle Victoria by Margaret Merry+add a dragon to the picture/   output_text: The Alhambra From Calle Victoria by Margaret Merry+add a dragon to the picture/book$1.00$1.00$
# input_text: Winter Wycoller - Lancashire. Painting by Keith Melling+turn it into a photograph/   output_text: Winter Wycoller - Lancashire. Painting by Keith Melling+turn it into a photograph/photo.
#
# The painting is a very simple
# input_text: French Cheese Shop Painting  - French Cheese Shop Fine Art Print+turn the cheese shop into a clothing store/   output_text: French Cheese Shop Painting  - French Cheese Shop Fine Art Print+turn the cheese shop into a clothing store/shop. The shop is located in the middle of
# input_text: Tomorrowland-Syd-Mead-Concept-Art (1)+put it in the ocean/   output_text: Tomorrowland-Syd-Mead-Concept-Art (1)+put it in the ocean/water/whatever you want/whatever you want/
# input_text: Skippool Creek by Jim Keating - Landscapes Waterscapes ( tranquil, #garyfongdramaticlight, #wtfbobdavis, dawn, relax, creek, yacht, tranquility, sunrise, relaxing, boat,  )+Make the colors more vibrant/   output_text: Skippool Creek by Jim Keating - Landscapes Waterscapes ( tranquil, #garyfongdramaticlight, #wtfbobdavis, dawn, relax, creek, yacht, tranquility, sunrise, relaxing, boat,  )+Make the colors more vibrant/blurred/blurred/blurred/bl
# input_text: ARt Prints of Canyon Stream by Elmer Wachtel+NONE/   output_text: ARt Prints of Canyon Stream by Elmer Wachtel+NONE/SUNY/SUNY/SUN
# input_text: The Reader in White by Meissonier+Make it blue/   output_text: The Reader in White by Meissonier+Make it blue/white/black/white/black/white/
# input_text: 2. FAROE ISLANDS: An archipelago of 18 mountainous isles in the North Atlantic Ocean between Norway and Iceland, the Faroe Islands has 'everything you could hope for', according to Big 7 Travel. It boasts 'crystal clear waterfalls, rocky cliffs that seem to jut out of nowhere and velvety green hills'+make the isles all white marble/   output_text: 2. FAROE ISLANDS: An archipelago of 18 mountainous isles in the North Atlantic Ocean between Norway and Iceland, the Faroe Islands has 'everything you could hope for', according to Big 7 Travel. It boasts 'crystal clear waterfalls, rocky cliffs that seem to jut out of nowhere and velvety green hills'+make the isles all white marble/coral reefs+the isles are covered in
# input_text: Happy 100th Birthday, Robert Doisneau! The classic, of course, The Kiss.+make the couple bears/   output_text: Happy 100th Birthday, Robert Doisneau! The classic, of course, The Kiss.+make the couple bears/cute little bears.+make the couple bears
# input_text: 'The Cottage Garden' by Abbott Fuller Graves (1859-1936), oil on canvas, 25 1/4 x 30 1/8 inches, signed lower right: 'Abbott Graves', circa 1925+As a photograph by Frédéric Kibas./   output_text: 'The Cottage Garden' by Abbott Fuller Graves (1859-1936), oil on canvas, 25 1/4 x 30 1/8 inches, signed lower right: 'Abbott Graves', circa 1925+As a photograph by Frédéric Kibas./Photograph by Frédéric Kib
# input_text: Peaceful Grove by Nicky Boehme+add a forest of redwood trees/   output_text: Peaceful Grove by Nicky Boehme+add a forest of redwood trees/coral moss/coral moss/coral
# input_text: Blue Lake And Early Winter Spires Poster+swapped with a beach/   output_text: Blue Lake And Early Winter Spires Poster+swapped with a beach/cave/cave/cave/c
# input_text: Village Court - Counted cross stitch pattern in PDF format by Maxispatterns on Etsy+Make it a Charles Addams cartoon/   output_text: Village Court - Counted cross stitch pattern in PDF format by Maxispatterns on Etsy+Make it a Charles Addams cartoon/animation by Maxispatterns on Etsy+
# input_text: Original vector oil painting of sea and beach on canvas. Rich golden Sun over sea. Modern Realism Impressionism. Black Sea coast near Yalta.+Make the painting a photograph/   output_text: Original vector oil painting of sea and beach on canvas. Rich golden Sun over sea. Modern Realism Impressionism. Black Sea coast near Yalta.+Make the painting a photograph/photo.+Make the painting a picture/photo
# input_text: italy-dolomites-hiking-train-lake-braies+add a stormy sky/   output_text: italy-dolomites-hiking-train-lake-braies+add a stormy sky/watercolor=red+$1$1$
# input_text: Old Hospital by Þorsteinn H. Ingibergsson - Landscapes Cloud Formations ( clouds, iceland, sky, nature, structor, landscape, abandoned )+Make it a modern hospital/   output_text: Old Hospital by Þorsteinn H. Ingibergsson - Landscapes Cloud Formations ( clouds, iceland, sky, nature, structor, landscape, abandoned )+Make it a modern hospital/hospital/hospital/hospital/hospital/hospital/
